# %%
import json
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

base_path = r"/Users/eduardo.lpereira/workspace/MAC6958/dataset/audio-video/Webrtc_internals_dataset"

# %%
def find_property(data, property_prefix, property_suffix):
    value = next(((k, v) for k, v in data.items() if k.startswith(property_prefix) and k.endswith(property_suffix)), None)
    if value is None:
        return None, None
    k, v = value
    v['values'] = json.loads(v['values'])
    
    return k, v

def read_internals(file_path):
    f = open(file_path)
 
    data = json.load(f)
    stats = data['PeerConnections'][next(iter(data['PeerConnections']))]['stats']

    prop, video_packets_lost = find_property(stats,'RTCRemoteInboundRtpVideoStream_','-packetsLost')

    prop, video_jitter = find_property(stats,'RTCRemoteInboundRtpVideoStream_','-jitter')

    prop, audio_packets_lost = find_property(stats,'RTCRemoteInboundRtpAudioStream_','-packetsLost')

    prop, audio_jitter = find_property(stats,'RTCRemoteInboundRtpAudioStream_','-jitter')
    
    return video_packets_lost, video_jitter, audio_packets_lost, audio_jitter

# %% [markdown]
# ### Read data

# %%
users_folders = [f for f in Path(base_path).rglob('User*')]

webrtc_internals = []

for user_folder in users_folders:
    #webrtc_internals = []
    user = user_folder.name
    
    #print(user)
    
    user_files = [f for f in user_folder.rglob('webrtc_internals_dump*')]
    for file in user_files:
        
        data = {}
        parts = file.name.split('-')  
        tc_parts = parts[1].split('_')
        data['user'] = user
        data['tc'] = tc_parts[0]
        data['delay'] = tc_parts[1]
        data['jitter'] = parts[2]
        data['packet_loss'] = parts[3].split('.')[0]
        video_packets_lost, video_jitter, audio_packets_lost, audio_jitter = read_internals(file)
        data['video_packets_lost'] = video_packets_lost
        data['video_jitter'] = video_jitter
        data['audio_packets_lost'] = audio_packets_lost
        data['audio_jitter'] = audio_jitter
        
        if audio_packets_lost is None:
            print('Skipping {}, {}: there is no values on audio_packets_lost'.format(user, data['tc']))
            continue
        
        len_itens = len(audio_packets_lost['values'])
        if len_itens < 120:
            print('Skipping {}, {}: it contains {} values on audio_packets_lost'.format(user, data['tc'], len_itens))
            continue
        
        len_itens = len(video_packets_lost['values'])
        if len_itens < 120:
            print('Skipping {}, {}: it contains {} values on video_packets_lost'.format(user, data['tc'], len_itens))
            continue
            
        #packet lost is incremental - calculating each second loss
        video_packets_lost_processed = {}
        video_packets_lost_processed['values'] = []
        for i in range(len_itens):
            if i == 0:
                video_packets_lost_processed['values'].append(video_packets_lost['values'][i])
            else:
                video_packets_lost_processed['values'].append(video_packets_lost['values'][i]-video_packets_lost['values'][i-1])
        data['video_packets_lost_processed'] = video_packets_lost_processed
        
        
        audio_packets_lost_processed = {}
        audio_packets_lost_processed['values'] = []
        for i in range(len(audio_packets_lost['values'])):
            if i == 0:
                audio_packets_lost_processed['values'].append(audio_packets_lost['values'][i])
            else:
                audio_packets_lost_processed['values'].append(audio_packets_lost['values'][i]-audio_packets_lost['values'][i-1])
        data['audio_packets_lost_processed'] = audio_packets_lost_processed
        
        webrtc_internals.append(data)
    
    #plot_data('TC11', 'video_packets_lost')
# Out:
# Skipping User15, TC15: there is no values on audio_packets_lost
# Skipping User6, TC10: it contains 114 values on audio_packets_lost
# Skipping User6, TC12: it contains 112 values on audio_packets_lost
# Skipping User6, TC13: it contains 109 values on audio_packets_lost
# Skipping User10, TC2: it contains 4 values on audio_packets_lost
# Skipping User16, TC15: it contains 116 values on audio_packets_lost
# Skipping User16, TC12: it contains 111 values on audio_packets_lost
# Skipping User18, TC8: there is no values on audio_packets_lost

# %% [markdown]
# ### Plot data

# %%
def plot_data(tc,internal, bins=None):
    # Filter data for tc equals TC11
    tc11_data = [item for item in webrtc_internals if item['tc'] == tc]
    #print(tc11_data)

    # Extract video_packets_lost.values and convert to numpy arrays
    packets_lost_values = []
    for item in tc11_data:
        values = item[internal]['values']
        
        if bins is not None:
            values = np.digitize(values, bins=bins)
        
        # getting first 2 minutes
        packets_lost_values.append(values[:120])
        #print(len(values[:120]))

        
    # Convert list of lists to a numpy array
    packets_lost_values = np.array(packets_lost_values)

    # Calculate mean and standard deviation along the columns (axis=0)
    
    mean_values = np.mean(packets_lost_values, axis=0)
    std_values = np.std(packets_lost_values, axis=0)

    # Plotting
    plt.figure(figsize=(10, 5))
    plt.errorbar(range(len(mean_values)), mean_values, yerr=std_values, fmt='-o', capsize=5)
    plt.title('Mean and Standard Deviation of {} ({})'.format(internal, tc))
    plt.xlabel('Index')
    plt.ylabel(internal)
    plt.grid(True)
    plt.savefig('img/internals_{}_{}.png'.format(internal, tc))
    plt.show()
    
def plot_all_data(tc):
    plot_data(tc, 'video_packets_lost')
    plot_data(tc, 'video_packets_lost_processed')
    plot_data(tc, 'video_jitter')
    plot_data(tc, 'audio_packets_lost')
    plot_data(tc, 'audio_packets_lost_processed')
    plot_data(tc, 'audio_jitter')

# %%
from IPython.display import Image
Image("img/TCs.png")

# %%
plot_all_data('TC11')

# %%
max_video_packets_lost = 0
max_video_packets_lost_processed = 0
max_video_jitter = 0
max_audio_packets_lost = 0
max_audio_packets_lost_processed = 0
max_audio_jitter = 0

for t in webrtc_internals:
    max_video_packets_lost = max(max_video_packets_lost, max(t['video_packets_lost']['values']))
    max_video_packets_lost_processed = max(max_video_packets_lost,max(t['video_packets_lost_processed']['values']))
    max_video_jitter = max(max_video_jitter,max(t['video_jitter']['values']))
    max_audio_packets_lost = max(max_audio_packets_lost, max(t['audio_packets_lost']['values']))
    max_audio_packets_lost_processed = max(max_audio_packets_lost,max(t['audio_packets_lost_processed']['values']))
    max_audio_jitter = max(max_audio_jitter,max(t['audio_jitter']['values']))
    
    
print('max_video_packets_lost', max_video_packets_lost)
print('max_video_packets_lost_processed', max_video_packets_lost_processed)
print('max_video_jitter', max_video_jitter)
print('max_audio_packets_lost', max_audio_packets_lost)
print('max_audio_packets_lost_processed', max_audio_packets_lost_processed)
print('max_audio_jitter', max_audio_jitter)
# Out:
# max_video_packets_lost 2616
# max_video_packets_lost_processed 2616
# max_video_jitter 1.7621
# max_audio_packets_lost 1967
# max_audio_packets_lost_processed 1967
# max_audio_jitter 0.1376875

# %%
plot_data('TC6', 'audio_packets_lost_processed')
plot_data('TC6', 'audio_packets_lost_processed', [0,10, 20, 30, 40, 50])

# %% [markdown]
# # Working with Openface data

# %%
import os
import pandas as pd
import numpy as np
import re

data_root = r"/Users/eduardo.lpereira/workspace/MAC6958/transformer-webrtc-2024"
num_lines = 3600

# %%
files = [f for f in Path(data_root, 'data/raw/Facial_expression_features_dataset').rglob('TC*.csv')]

# %%
def read_user_tc(f):
    user = str(f).split('/')[-2]
    from_name= re.split('[_\-.]', f.name)[:-1]
    return user, from_name[0]

# Initialize lists to hold the data and targets
data_sequences = []
target_sequences = []

tc_11_target_sequences = []
tc_5_target_sequences = []

# Process each file
for file_path in files:
    
    user, tc = read_user_tc(file_path)
    
    #if user != 'User1' or tc != 'TC11':
    #if tc != 'TC1' and tc != 'TC6' and tc != 'TC11':
        #print('Skip {}'.format(tc))
        #continue

    # Read the first 3600 lines of the file
    df = pd.read_csv(file_path, nrows=num_lines)
    
    if len(df) < 3600:
        print('Skipping {}, {} invalid face features data, len {}'.format(user,tc,len(df)))
        continue
        
    data_internals = [item for item in webrtc_internals if item['user'] == user and item['tc'] == tc]
    
    if len(data_internals) == 0:
        print('Skipping {}, {} no Internals'.format(user,tc))
        continue
        
    video_packets_lost = data_internals[0]['video_packets_lost_processed']['values']
    video_jitter = data_internals[0]['video_jitter']['values']
    audio_packets_lost = data_internals[0]['audio_packets_lost_processed']['values']
    audio_jitter = data_internals[0]['audio_jitter']['values']
    
    #categorizing target
    #video_packets_lost = np.digitize(video_packets_lost, bins=[0,10, 20, 30, 40, 50])
    #audio_packets_lost = np.digitize(audio_packets_lost, bins=[0,5,10,15, 20,25, 30, 40, 50])/10
    #video_jitter = np.digitize(video_jitter, bins=[0,0.25,0.5,0.75,1])
    #audio_jitter = np.digitize(audio_jitter, bins=[0,0.025,0.05,0.075,0.1])

    # Reshape the data into sequences of 30 frames
    
    factor = 5
    frames = 30
    
    target_idx = 0
    
    for f in range(frames):
        num_sequences = num_lines // (factor*frames)
        for i in range(num_sequences):
            start_idx = i * (factor*frames)
            end_idx = (i + 1) * (factor*frames)

            sequence = []
            for j in range(factor):
                # Extract the sequence of 30 frames
                # Select only the feature columns (starting from the 4th column)
                start_idx_2 = start_idx + (j * frames) + f
                #print('j {}, start_idx {}, start_idx_2 {}'.format(j,start_idx, start_idx_2))

                d = df.iloc[start_idx_2:start_idx_2+1, 5:13].to_numpy()
                #print(d)
                sequence.append(d[0])

            if len(sequence) != 5:
                print('Invalid sequence')
                continue
            data_sequences.append(sequence)

            target_idx = i * factor

            # Generate targets
            #target = [video_packets_lost[i], video_jitter[i], audio_packets_lost[i], audio_jitter[i]]
            
            target = [np.mean(video_packets_lost[target_idx:target_idx+factor]), np.mean(audio_packets_lost[target_idx:target_idx+factor]), np.mean(video_jitter[target_idx:target_idx+factor]) , np.mean(audio_jitter[target_idx:target_idx+factor])]
            #target = [np.mean(video_packets_lost[target_idx:target_idx+factor]), np.mean(audio_packets_lost[target_idx:target_idx+factor])]
            
            
            #target = 0;
            #if tc == 'TC6':
            #    target = 1
            #if tc == 'TC11':
            #    target = 2
            
            if len(target) != 4:
                print('Invalid target')
                continue
            
            
            target_sequences.append(target)
            
            if tc == 'TC5':
                tc_5_target_sequences.append(target)
            
            if tc == 'TC11':
                tc_11_target_sequences.append(target)

# Convert lists to numpy arrays


X = np.array(data_sequences)
y = np.array(target_sequences)

y_tc5 = np.array(tc_5_target_sequences)
y_tc11 = np.array(tc_11_target_sequences)

# Verify the shapes
print('\n')
print(f'Input data shape: {X.shape}')
print(f'Target data shape: {y.shape}')
# Out:
# Skipping User5, TC9 invalid face features data, len 1811
# Skipping User5, TC14 invalid face features data, len 1811
# Skipping User5, TC3 invalid face features data, len 1811
# Skipping User5, TC7 invalid face features data, len 1811
# Skipping User5, TC4 invalid face features data, len 1812
# Skipping User5, TC1 invalid face features data, len 1811
# Skipping User5, TC5 invalid face features data, len 1811
# Skipping User5, TC13 invalid face features data, len 1811
# Skipping User5, TC2 invalid face features data, len 1811
# Skipping User5, TC11 invalid face features data, len 1811
# Skipping User5, TC10 invalid face features data, len 1812
# Skipping User5, TC15 invalid face features data, len 1811
# Skipping User5, TC6 invalid face features data, len 1812
# Skipping User5, TC8 invalid face features data, len 1811
# Skipping User5, TC12 invalid face features data, len 428
# Skipping User3, TC15 invalid face features data, len 1127
# Skipping User14, TC9 invalid face features data, len 722
# Skipping User12, TC14 invalid face features data, len 530
# Skipping User15, TC15 invalid face features data, len 2150
# Skipping User6, TC13 no Internals
# Skipping User6, TC10 no Internals
# Skipping User6, TC12 no Internals
# Skipping User1, TC15 invalid face features data, len 205
# Skipping User9, TC14 invalid face features data, len 290
# Skipping User10, TC2 no Internals
# Skipping User10, TC12 invalid face features data, len 741
# Skipping User17, TC7 invalid face features data, len 2021
# Skipping User17, TC15 invalid face features data, len 3570
# Skipping User16, TC15 no Internals
# Skipping User16, TC12 no Internals
# Skipping User18, TC9 invalid face features data, len 782
# Skipping User18, TC8 no Internals
#
#
# Input data shape: (192960, 5, 8)
# Target data shape: (192960, 4)

# %%
for i in range(192960):
    for j in range(5):
        if len(X[i][j]) != 8:
            print('Invalid x')
    
    if len(y[i]) != 4:
        print('Invalid y')

# %%
import pandas as pd

# Reading a CSV file
#df = pd.read_csv('/Users/eduardo.lpereira/workspace/MAC6958/transformer-webrtc-2024/data/raw/Facial_expression_features_dataset/User1/TC11_0-0-30.csv')

#selected_columns = df['confidence', 'success', 'gaze_0_x', 'gaze_0_y', 'gaze_0_z', 'gaze_1_x', 'gaze_1_y', 'gaze_1_z', 'gaze_angle_x', 'gaze_angle_y']

#selected_columns = df['confidence']

# Display the first few rows of the DataFrame
#print(df.head())

#start = 6


#print(df.iloc[:, [3,5, 6, 7, 8 ,9, 10, 11, 12]].iloc[start:start+1])

# %%
#X[1]
#y

# %% [markdown]
# # Training

# %% [markdown]
# ### Data preparation

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, LSTM, Flatten, GRU, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix

# %%
# encode categories

def encode_into_bins(array, bin_def_array):
    number_of_bins = 6
    
    # Discretize each feature into bins
    # 6 bins require 7 edges
    bins = np.linspace(np.min(bin_def_array), np.max(bin_def_array), number_of_bins+1)  
    #print('bins: {}'.format(bins))
    
    # `np.digitize` returns bin index; subtract 1 for zero-based labels
    encoded = np.digitize(array, bins) - 1
    
    #ensure labels
    encoded[encoded == number_of_bins] = (number_of_bins -1)
    encoded[encoded == -1] = 0
    
    return encoded


video_packets_loss_encoded = encode_into_bins(y[:, 0], y_tc11[:, 0])
audio_packets_loss_encoded = encode_into_bins(y[:, 1], y_tc11[:, 1])
video_jitter_encoded = encode_into_bins(y[:, 2], y_tc5[:, 2])
audio_jitter_encoded = encode_into_bins(y[:, 3], y_tc5[:, 3])

# Combine the encoded values
y_2 = np.stack((video_packets_loss_encoded, audio_packets_loss_encoded, video_jitter_encoded, audio_jitter_encoded), axis=1)

for i in range(0,4):
    print(i,set(y_2[:,i]))
# Out:
# 0 {0, 1, 2, 3, 4, 5}
# 1 {0, 1, 2, 3, 4, 5}
# 2 {0, 1, 2, 3, 4, 5}
# 3 {0, 1, 2, 3, 4, 5}

# %%
from collections import Counter

counts = Counter(video_packets_loss_encoded)
print('video_packets_loss_encoded: {}'.format(counts))

counts = Counter(audio_packets_loss_encoded)
print('audio_packets_loss_encoded: {}'.format(counts))

counts = Counter(video_jitter_encoded)
print('video_jitter_encoded: {}'.format(counts))

counts = Counter(audio_jitter_encoded)
print('audio_jitter_encoded: {}'.format(counts))
# Out:
# video_packets_loss_encoded: Counter({0: 172980, 1: 16380, 2: 2610, 3: 480, 4: 300, 5: 210})
# audio_packets_loss_encoded: Counter({0: 137730, 1: 40530, 2: 10320, 3: 2850, 4: 1080, 5: 450})
# video_jitter_encoded: Counter({0: 136380, 3: 27210, 2: 12060, 4: 11880, 1: 4650, 5: 780})
# audio_jitter_encoded: Counter({0: 130290, 4: 29010, 5: 21240, 3: 10230, 2: 1230, 1: 960})

# %%
# If `y` is not already in integer format, convert it.
# Example: if `y` contains continuous values, you might need to bin them into classes
#y_2 = np.digitize(y, bins=[0.1, 0.2, 0.3, 0.4])
#y_2 = y.astype('int64')

#y_2 = to_categorical(y, num_classes=3)

#scaler_y = StandardScaler()
#y_2 = scaler_y.fit_transform(y.reshape(-1, y.shape[-1])).reshape(y.shape)

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X.reshape(-1, X.shape[-1])).reshape(X.shape)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_2, test_size=0.2, random_state=42)

# Standardize the input data
#scaler = StandardScaler()
#X_train = scaler.fit_transform(X_train.reshape(-1, X_train.shape[-1])).reshape(X_train.shape)
#X_test = scaler.transform(X_test.reshape(-1, X_test.shape[-1])).reshape(X_test.shape)

# Check the shapes
print(f'X_train shape: {X_train.shape}')
print(f'X_test shape: {X_test.shape}')
print(f'y_train shape: {y_train.shape}')
print(f'y_test shape: {y_test.shape}')
# Out:
# X_train shape: (154368, 5, 8)
# X_test shape: (38592, 5, 8)
# y_train shape: (154368, 4)
# y_test shape: (38592, 4)

# %% [markdown]
# ### Build the Model

# %%
def append_history(history, new_history):
    for key in history.history.keys():
        history.history[key].extend(new_history.history[key])

# %%
# Define the input layer
input_layer = Input(shape=(X_train.shape[1], X_train.shape[2]))  # Replace input_dim with your input dimension

gru_1 = GRU(128, return_sequences=True)(input_layer)
batch_1 = BatchNormalization()(gru_1)
gru_2 = GRU(64, return_sequences=False)(batch_1)
batch_2 = BatchNormalization()(gru_2)
dense_1 = tf.keras.layers.Dense(32, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(batch_2)
drop_1 = tf.keras.layers.Dropout(0.2)(dense_1)
dense_2 = tf.keras.layers.Dense(32, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(drop_1)
drop_2 = tf.keras.layers.Dropout(0.2)(dense_2)
hidden_layer = drop_2

# Define separate output layers for each feature
output_video_packets_loss = Dense(6, activation='softmax', name='video_packets_loss_output')(hidden_layer)  # 6 categories
output_audio_packets_loss = Dense(6, activation='softmax', name='audio_packets_loss_output')(hidden_layer)  # 6 categories
output_video_jitter = Dense(6, activation='softmax', name='video_jitter_output')(hidden_layer)  # 6 categories
output_audio_jitter = Dense(6, activation='softmax', name='audio_jitter_output')(hidden_layer)  # 6 categories

# Define the model with multiple outputs
model = Model(inputs=input_layer, outputs=[output_video_packets_loss, output_audio_packets_loss, output_video_jitter, output_audio_jitter])

# Compile the model
model.compile(optimizer='adam',
                  loss={'video_packets_loss_output': 'SparseCategoricalCrossentropy',
                        'audio_packets_loss_output': 'SparseCategoricalCrossentropy',
                        'video_jitter_output': 'SparseCategoricalCrossentropy',
                        'audio_jitter_output': 'SparseCategoricalCrossentropy'},
                  metrics=['accuracy'])

model.summary()
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_9 (InputLayer)        [(None, 5, 8)]               0         []
#
#  gru_15 (GRU)                (None, 5, 128)               52992     ['input_9[0][0]']
#
#  batch_normalization_14 (Ba  (None, 5, 128)               512       ['gru_15[0][0]']
#  tchNormalization)
#
#  gru_16 (GRU)                (None, 64)                   37248     ['batch_normalization_14[0][0]
#                                                                     ']
#
#  batch_normalization_15 (Ba  (None, 64)                   256       ['gru_16[0][0]']
#  tchNormalization)
#
#  dense_14 (Dense)            (None, 32)                   2080      ['batch_normalization_15[0][0]
#                                                                     ']
#
#  dropout_14 (Dropout)        (None, 32)                   0         ['dense_14[0][0]']
#
#  dense_15 (Dense)            (None, 32)                   1056      ['dropout_14[0][0]']
#
#  dropout_15 (Dropout)        (None, 32)                   0         ['dense_15[0][0]']
#
#  video_packets_loss_output   (None, 6)                    198       ['dropout_15[0][0]']
#  (Dense)
#
#  audio_packets_loss_output   (None, 6)                    198       ['dropout_15[0][0]']
#  (Dense)
#
#  video_jitter_output (Dense  (None, 6)                    198       ['dropout_15[0][0]']
#  )
#
#  audio_jitter_output (Dense  (None, 6)                    198       ['dropout_15[0][0]']
#  )
#
# ==================================================================================================
# Total params: 94936 (370.84 KB)
# Trainable params: 94552 (369.34 KB)
# Non-trainable params: 384 (1.50 KB)
# __________________________________________________________________________________________________

# %%
def combine_histories(history_list):
    combined_history = {}
    for history in history_list:
        for key, values in history.history.items():
            if key not in combined_history:
                combined_history[key] = values
            else:
                combined_history[key].extend(values)
    return combined_history

history_list = []

for i in range(10):
    print('\n\n ***** TRAINING {}'.format(i))
    history = model.fit(X_train, [y_train[:,0], y_train[:,1], y_train[:,2], y_train[:,3]],
          epochs = 10,
          batch_size=32,
          validation_data = (X_test, [y_test[:,0], y_test[:,1], y_test[:,2], y_test[:,3]])
        )
    history_list.append(history)
# Out:
#  ***** TRAINING 0
# Epoch 1/10
# 4824/4824 [==============================] - 20s 4ms/step - loss: 3.3150 - video_packets_loss_output_loss: 0.4156 - audio_packets_loss_output_loss: 0.8552 - video_jitter_output_loss: 0.9184 - audio_jitter_output_loss: 1.0055 - video_packets_loss_output_accuracy: 0.8953 - audio_packets_loss_output_accuracy: 0.7086 - video_jitter_output_accuracy: 0.7006 - audio_jitter_output_accuracy: 0.6713 - val_loss: 3.0044 - val_video_packets_loss_output_loss: 0.3953 - val_audio_packets_loss_output_loss: 0.8202 - val_video_jitter_output_loss: 0.8142 - val_audio_jitter_output_loss: 0.9514 - val_video_packets_loss_output_accuracy: 0.8959 - val_audio_packets_loss_output_accuracy: 0.7174 - val_video_jitter_output_accuracy: 0.7093 - val_audio_jitter_output_accuracy: 0.6736
# Epoch 2/10
# 4824/4824 [==============================] - 18s 4ms/step - loss: 3.0119 - video_packets_loss_output_loss: 0.3930 - audio_packets_loss_output_loss: 0.8296 - video_jitter_output_loss: 0.8206 - audio_jitter_output_loss: 0.9410 - video_packets_loss_output_accuracy: 0.8966 - audio_packets_loss_output_accuracy: 0.7129 - video_jitter_output_accuracy: 0.7102 - audio_jitter_output_accuracy: 0.6795 - val_loss: 2.8908 - val_video_packets_loss_output_loss: 0.3872 - val_audio_packets_loss_output_loss: 0.8113 - val_video_jitter_output_loss: 0.7584 - val_audio_jitter_output_loss: 0.9036 - val_video_packets_loss_output_accuracy: 0.8959 - val_audio_packets_loss_output_accuracy: 0.7174 - val_video_jitter_output_accuracy: 0.7225 - val_audio_jitter_output_accuracy: 0.6850
# Epoch 3/10
# 4824/4824 [==============================] - 18s 4ms/step - loss: 2.9068 - video_packets_loss_output_loss: 0.3850 - audio_packets_loss_output_loss: 0.8196 - video_jitter_output_loss: 0.7725 - audio_jitter_output_loss: 0.8962 - video_packets_loss_output_accuracy: 0.8966 - audio_packets_loss_output_accuracy: 0.7129 - video_jitter_output_accuracy: 0.7222 - audio_jitter_output_accuracy: 0.6872 - val_loss: 2.7908 - val_video_packets_loss_output_loss: 0.3808 - val_audio_packets_loss_output_loss: 0.7988 - val_video_jitter_output_loss: 0.7207 - val_audio_jitter_output_loss: 0.8549 - val_video_packets_loss_output_accuracy: 0.8959 - val_audio_packets_loss_output_accuracy: 0.7174 - val_video_jitter_output_accuracy: 0.7369 - val_audio_jitter_output_accuracy: 0.6978
# Epoch 4/10
# 4824/4824 [==============================] - 18s 4ms/step - loss: 2.8115 - video_packets_loss_output_loss: 0.3790 - audio_packets_loss_output_loss: 0.8070 - video_jitter_output_loss: 0.7345 - audio_jitter_output_loss: 0.8522 - video_packets_loss_output_accuracy: 0.8966 - audio_packets_loss_output_accuracy: 0.7129 - video_jitter_output_accuracy: 0.7340 - audio_jitter_output_accuracy: 0.6969 - val_loss: 2.7093 - val_video_packets_loss_output_loss: 0.3734 - val_audio_packets_loss_output_loss: 0.7837 - val_video_jitter_output_loss: 0.6896 - val_audio_jitter_output_loss: 0.8234 - val_video_packets_loss_output_accuracy: 0.8959 - val_audio_packets_loss_output_accuracy: 0.7174 - val_video_jitter_output_accuracy: 0.7436 - val_audio_jitter_output_accuracy: 0.7055
# Epoch 5/10
# 4824/4824 [==============================] - 19s 4ms/step - loss: 2.7273 - video_packets_loss_output_loss: 0.3719 - audio_packets_loss_output_loss: 0.7904 - video_jitter_output_loss: 0.7057 - audio_jitter_output_loss: 0.8173 - video_packets_loss_output_accuracy: 0.8966 - audio_packets_loss_output_accuracy: 0.7142 - video_jitter_output_accuracy: 0.7455 - audio_jitter_output_accuracy: 0.7067 - val_loss: 2.6135 - val_video_packets_loss_output_loss: 0.3660 - val_audio_packets_loss_output_loss: 0.7642 - val_video_jitter_output_loss: 0.6610 - val_audio_jitter_output_loss: 0.7794 - val_video_packets_loss_output_accuracy: 0.8959 - val_audio_packets_loss_output_accuracy: 0.7210 - val_video_jitter_output_accuracy: 0.7605 - val_audio_jitter_output_accuracy: 0.7146
# Epoch 6/10
# 4824/4824 [==============================] - 20s 4ms/step - loss: 2.6462 - video_packets_loss_output_loss: 0.3653 - audio_packets_loss_output_loss: 0.7723 - video_jitter_output_loss: 0.6793 - audio_jitter_output_loss: 0.7844 - video_packets_loss_output_accuracy: 0.8965 - audio_packets_loss_output_accuracy: 0.7169 - video_jitter_output_accuracy: 0.7537 - audio_jitter_output_accuracy: 0.7152 - val_loss: 2.5527 - val_video_packets_loss_output_loss: 0.3595 - val_audio_packets_loss_output_loss: 0.7416 - val_video_jitter_output_loss: 0.6480 - val_audio_jitter_output_loss: 0.7594 - val_video_packets_loss_output_accuracy: 0.8959 - val_audio_packets_loss_output_accuracy: 0.7233 - val_video_jitter_output_accuracy: 0.7655 - val_audio_jitter_output_accuracy: 0.7270
# Epoch 7/10
# 4824/4824 [==============================] - 19s 4ms/step - loss: 2.5783 - video_packets_loss_output_loss: 0.3585 - audio_packets_loss_output_loss: 0.7530 - video_jitter_output_loss: 0.6604 - audio_jitter_output_loss: 0.7598 - video_packets_loss_output_accuracy: 0.8964 - audio_packets_loss_output_accuracy: 0.7217 - video_jitter_output_accuracy: 0.7614 - audio_jitter_output_accuracy: 0.7237 - val_loss: 2.4811 - val_video_packets_loss_output_loss: 0.3532 - val_audio_packets_loss_output_loss: 0.7265 - val_video_jitter_output_loss: 0.6219 - val_audio_jitter_output_loss: 0.7313 - val_video_packets_loss_output_accuracy: 0.8959 - val_audio_packets_loss_output_accuracy: 0.7313 - val_video_jitter_output_accuracy: 0.7712 - val_audio_jitter_output_accuracy: 0.7322
# Epoch 8/10
# 4824/4824 [==============================] - 21s 4ms/step - loss: 2.5115 - video_packets_loss_output_loss: 0.3528 - audio_packets_loss_output_loss: 0.7354 - video_jitter_output_loss: 0.6422 - audio_jitter_output_loss: 0.7329 - video_packets_loss_output_accuracy: 0.8964 - audio_packets_loss_output_accuracy: 0.7271 - video_jitter_output_accuracy: 0.7687 - audio_jitter_output_accuracy: 0.7308 - val_loss: 2.4213 - val_video_packets_loss_output_loss: 0.3489 - val_audio_packets_loss_output_loss: 0.7099 - val_video_jitter_output_loss: 0.6065 - val_audio_jitter_output_loss: 0.7081 - val_video_packets_loss_output_accuracy: 0.8959 - val_audio_packets_loss_output_accuracy: 0.7383 - val_video_jitter_output_accuracy: 0.7791 - val_audio_jitter_output_accuracy: 0.7414
# Epoch 9/10
# 4824/4824 [==============================] - 22s 4ms/step - loss: 2.4591 - video_packets_loss_output_loss: 0.3477 - audio_packets_loss_output_loss: 0.7195 - video_jitter_output_loss: 0.6289 - audio_jitter_output_loss: 0.7140 - video_packets_loss_output_accuracy: 0.8963 - audio_packets_loss_output_accuracy: 0.7319 - video_jitter_output_accuracy: 0.7732 - audio_jitter_output_accuracy: 0.7365 - val_loss: 2.3601 - val_video_packets_loss_output_loss: 0.3433 - val_audio_packets_loss_output_loss: 0.6871 - val_video_jitter_output_loss: 0.5901 - val_audio_jitter_output_loss: 0.6907 - val_video_packets_loss_output_accuracy: 0.8960 - val_audio_packets_loss_output_accuracy: 0.7425 - val_video_jitter_output_accuracy: 0.7847 - val_audio_jitter_output_accuracy: 0.7465
# Epoch 10/10
# 4824/4824 [==============================] - 21s 4ms/step - loss: 2.4103 - video_packets_loss_output_loss: 0.3449 - audio_packets_loss_output_loss: 0.7021 - video_jitter_output_loss: 0.6166 - audio_jitter_output_loss: 0.6964 - video_packets_loss_output_accuracy: 0.8964 - audio_packets_loss_output_accuracy: 0.7383 - video_jitter_output_accuracy: 0.7775 - audio_jitter_output_accuracy: 0.7429 - val_loss: 2.3337 - val_video_packets_loss_output_loss: 0.3428 - val_audio_packets_loss_output_loss: 0.6799 - val_video_jitter_output_loss: 0.5893 - val_audio_jitter_output_loss: 0.6735 - val_video_packets_loss_output_accuracy: 0.8961 - val_audio_packets_loss_output_accuracy: 0.7463 - val_video_jitter_output_accuracy: 0.7836 - val_audio_jitter_output_accuracy: 0.7488
#
#
#  ***** TRAINING 1
# Epoch 1/10
# 4824/4824 [==============================] - 21s 4ms/step - loss: 2.3669 - video_packets_loss_output_loss: 0.3404 - audio_packets_loss_output_loss: 0.6902 - video_jitter_output_loss: 0.6058 - audio_jitter_output_loss: 0.6801 - video_packets_loss_output_accuracy: 0.8967 - audio_packets_loss_output_accuracy: 0.7421 - video_jitter_output_accuracy: 0.7798 - audio_jitter_output_accuracy: 0.7483 - val_loss: 2.2873 - val_video_packets_loss_output_loss: 0.3403 - val_audio_packets_loss_output_loss: 0.6622 - val_video_jitter_output_loss: 0.5740 - val_audio_jitter_output_loss: 0.6613 - val_video_packets_loss_output_accuracy: 0.8960 - val_audio_packets_loss_output_accuracy: 0.7531 - val_video_jitter_output_accuracy: 0.7890 - val_audio_jitter_output_accuracy: 0.7587
# Epoch 2/10
# 4824/4824 [==============================] - 21s 4ms/step - loss: 2.3253 - video_packets_loss_output_loss: 0.3385 - audio_packets_loss_output_loss: 0.6738 - video_jitter_output_loss: 0.5950 - audio_jitter_output_loss: 0.6666 - video_packets_loss_output_accuracy: 0.8962 - audio_packets_loss_output_accuracy: 0.7479 - video_jitter_output_accuracy: 0.7843 - audio_jitter_output_accuracy: 0.7529 - val_loss: 2.2601 - val_video_packets_loss_output_loss: 0.3368 - val_audio_packets_loss_output_loss: 0.6470 - val_video_jitter_output_loss: 0.5695 - val_audio_jitter_output_loss: 0.6546 - val_video_packets_loss_output_accuracy: 0.8961 - val_audio_packets_loss_output_accuracy: 0.7607 - val_video_jitter_output_accuracy: 0.7904 - val_audio_jitter_output_accuracy: 0.7624
# Epoch 3/10
# 4824/4824 [==============================] - 21s 4ms/step - loss: 2.2937 - video_packets_loss_output_loss: 0.3367 - audio_packets_loss_output_loss: 0.6605 - video_jitter_output_loss: 0.5886 - audio_jitter_output_loss: 0.6561 - video_packets_loss_output_accuracy: 0.8965 - audio_packets_loss_output_accuracy: 0.7531 - video_jitter_output_accuracy: 0.7868 - audio_jitter_output_accuracy: 0.7573 - val_loss: 2.2333 - val_video_packets_loss_output_loss: 0.3363 - val_audio_packets_loss_output_loss: 0.6395 - val_video_jitter_output_loss: 0.5628 - val_audio_jitter_output_loss: 0.6425 - val_video_packets_loss_output_accuracy: 0.8966 - val_audio_packets_loss_output_accuracy: 0.7625 - val_video_jitter_output_accuracy: 0.7931 - val_audio_jitter_output_accuracy: 0.7621
# Epoch 4/10
# 4824/4824 [==============================] - 21s 4ms/step - loss: 2.2615 - video_packets_loss_output_loss: 0.3335 - audio_packets_loss_output_loss: 0.6515 - video_jitter_output_loss: 0.5801 - audio_jitter_output_loss: 0.6443 - video_packets_loss_output_accuracy: 0.8965 - audio_packets_loss_output_accuracy: 0.7560 - video_jitter_output_accuracy: 0.7897 - audio_jitter_output_accuracy: 0.7615 - val_loss: 2.1879 - val_video_packets_loss_output_loss: 0.3312 - val_audio_packets_loss_output_loss: 0.6289 - val_video_jitter_output_loss: 0.5512 - val_audio_jitter_output_loss: 0.6245 - val_video_packets_loss_output_accuracy: 0.8964 - val_audio_packets_loss_output_accuracy: 0.7653 - val_video_jitter_output_accuracy: 0.7965 - val_audio_jitter_output_accuracy: 0.7703
# Epoch 5/10
# 4824/4824 [==============================] - 21s 4ms/step - loss: 2.2322 - video_packets_loss_output_loss: 0.3309 - audio_packets_loss_output_loss: 0.6426 - video_jitter_output_loss: 0.5731 - audio_jitter_output_loss: 0.6327 - video_packets_loss_output_accuracy: 0.8965 - audio_packets_loss_output_accuracy: 0.7596 - video_jitter_output_accuracy: 0.7909 - audio_jitter_output_accuracy: 0.7645 - val_loss: 2.1847 - val_video_packets_loss_output_loss: 0.3282 - val_audio_packets_loss_output_loss: 0.6241 - val_video_jitter_output_loss: 0.5511 - val_audio_jitter_output_loss: 0.6293 - val_video_packets_loss_output_accuracy: 0.8961 - val_audio_packets_loss_output_accuracy: 0.7675 - val_video_jitter_output_accuracy: 0.7949 - val_audio_jitter_output_accuracy: 0.7703
# Epoch 6/10
# 4824/4824 [==============================] - 21s 4ms/step - loss: 2.2062 - video_packets_loss_output_loss: 0.3296 - audio_packets_loss_output_loss: 0.6324 - video_jitter_output_loss: 0.5663 - audio_jitter_output_loss: 0.6249 - video_packets_loss_output_accuracy: 0.8964 - audio_packets_loss_output_accuracy: 0.7649 - video_jitter_output_accuracy: 0.7940 - audio_jitter_output_accuracy: 0.7681 - val_loss: 2.1709 - val_video_packets_loss_output_loss: 0.3287 - val_audio_packets_loss_output_loss: 0.6129 - val_video_jitter_output_loss: 0.5538 - val_audio_jitter_output_loss: 0.6235 - val_video_packets_loss_output_accuracy: 0.8965 - val_audio_packets_loss_output_accuracy: 0.7729 - val_video_jitter_output_accuracy: 0.7950 - val_audio_jitter_output_accuracy: 0.7712
# Epoch 7/10
# 4824/4824 [==============================] - 21s 4ms/step - loss: 2.1834 - video_packets_loss_output_loss: 0.3270 - audio_packets_loss_output_loss: 0.6226 - video_jitter_output_loss: 0.5632 - audio_jitter_output_loss: 0.6171 - video_packets_loss_output_accuracy: 0.8966 - audio_packets_loss_output_accuracy: 0.7676 - video_jitter_output_accuracy: 0.7950 - audio_jitter_output_accuracy: 0.7706 - val_loss: 2.1522 - val_video_packets_loss_output_loss: 0.3267 - val_audio_packets_loss_output_loss: 0.6022 - val_video_jitter_output_loss: 0.5520 - val_audio_jitter_output_loss: 0.6178 - val_video_packets_loss_output_accuracy: 0.8961 - val_audio_packets_loss_output_accuracy: 0.7772 - val_video_jitter_output_accuracy: 0.7955 - val_audio_jitter_output_accuracy: 0.7697
# Epoch 8/10
# 4824/4824 [==============================] - 22s 4ms/step - loss: 2.1632 - video_packets_loss_output_loss: 0.3257 - audio_packets_loss_output_loss: 0.6142 - video_jitter_output_loss: 0.5568 - audio_jitter_output_loss: 0.6130 - video_packets_loss_output_accuracy: 0.8964 - audio_packets_loss_output_accuracy: 0.7719 - video_jitter_output_accuracy: 0.7973 - audio_jitter_output_accuracy: 0.7707 - val_loss: 2.1530 - val_video_packets_loss_output_loss: 0.3315 - val_audio_packets_loss_output_loss: 0.6008 - val_video_jitter_output_loss: 0.5549 - val_audio_jitter_output_loss: 0.6136 - val_video_packets_loss_output_accuracy: 0.8960 - val_audio_packets_loss_output_accuracy: 0.7786 - val_video_jitter_output_accuracy: 0.7940 - val_audio_jitter_output_accuracy: 0.7725
# Epoch 9/10
# 4824/4824 [==============================] - 20s 4ms/step - loss: 2.1402 - video_packets_loss_output_loss: 0.3251 - audio_packets_loss_output_loss: 0.6054 - video_jitter_output_loss: 0.5542 - audio_jitter_output_loss: 0.6015 - video_packets_loss_output_accuracy: 0.8963 - audio_packets_loss_output_accuracy: 0.7759 - video_jitter_output_accuracy: 0.7978 - audio_jitter_output_accuracy: 0.7748 - val_loss: 2.1204 - val_video_packets_loss_output_loss: 0.3255 - val_audio_packets_loss_output_loss: 0.5893 - val_video_jitter_output_loss: 0.5445 - val_audio_jitter_output_loss: 0.6076 - val_video_packets_loss_output_accuracy: 0.8962 - val_audio_packets_loss_output_accuracy: 0.7797 - val_video_jitter_output_accuracy: 0.8019 - val_audio_jitter_output_accuracy: 0.7785
# Epoch 10/10
# 4824/4824 [==============================] - 21s 4ms/step - loss: 2.1199 - video_packets_loss_output_loss: 0.3241 - audio_packets_loss_output_loss: 0.5977 - video_jitter_output_loss: 0.5469 - audio_jitter_output_loss: 0.5968 - video_packets_loss_output_accuracy: 0.8966 - audio_packets_loss_output_accuracy: 0.7778 - video_jitter_output_accuracy: 0.7998 - audio_jitter_output_accuracy: 0.7779 - val_loss: 2.1078 - val_video_packets_loss_output_loss: 0.3255 - val_audio_packets_loss_output_loss: 0.5868 - val_video_jitter_output_loss: 0.5375 - val_audio_jitter_output_loss: 0.6045 - val_video_packets_loss_output_accuracy: 0.8959 - val_audio_packets_loss_output_accuracy: 0.7833 - val_video_jitter_output_accuracy: 0.8027 - val_audio_jitter_output_accuracy: 0.7796
#
#
#  ***** TRAINING 2
# Epoch 1/10
# 4824/4824 [==============================] - 20s 4ms/step - loss: 2.1003 - video_packets_loss_output_loss: 0.3219 - audio_packets_loss_output_loss: 0.5879 - video_jitter_output_loss: 0.5459 - audio_jitter_output_loss: 0.5895 - video_packets_loss_output_accuracy: 0.8970 - audio_packets_loss_output_accuracy: 0.7821 - video_jitter_output_accuracy: 0.8010 - audio_jitter_output_accuracy: 0.7801 - val_loss: 2.0911 - val_video_packets_loss_output_loss: 0.3236 - val_audio_packets_loss_output_loss: 0.5811 - val_video_jitter_output_loss: 0.5353 - val_audio_jitter_output_loss: 0.5967 - val_video_packets_loss_output_accuracy: 0.8964 - val_audio_packets_loss_output_accuracy: 0.7851 - val_video_jitter_output_accuracy: 0.8026 - val_audio_jitter_output_accuracy: 0.7814
# Epoch 2/10
# 4824/4824 [==============================] - 19s 4ms/step - loss: 2.0854 - video_packets_loss_output_loss: 0.3211 - audio_packets_loss_output_loss: 0.5839 - video_jitter_output_loss: 0.5400 - audio_jitter_output_loss: 0.5853 - video_packets_loss_output_accuracy: 0.8967 - audio_packets_loss_output_accuracy: 0.7841 - video_jitter_output_accuracy: 0.8030 - audio_jitter_output_accuracy: 0.7816 - val_loss: 2.1003 - val_video_packets_loss_output_loss: 0.3258 - val_audio_packets_loss_output_loss: 0.5826 - val_video_jitter_output_loss: 0.5410 - val_audio_jitter_output_loss: 0.5972 - val_video_packets_loss_output_accuracy: 0.8961 - val_audio_packets_loss_output_accuracy: 0.7871 - val_video_jitter_output_accuracy: 0.8013 - val_audio_jitter_output_accuracy: 0.7818
# Epoch 3/10
# 4824/4824 [==============================] - 19s 4ms/step - loss: 2.0720 - video_packets_loss_output_loss: 0.3196 - audio_packets_loss_output_loss: 0.5772 - video_jitter_output_loss: 0.5382 - audio_jitter_output_loss: 0.5821 - video_packets_loss_output_accuracy: 0.8971 - audio_packets_loss_output_accuracy: 0.7861 - video_jitter_output_accuracy: 0.8033 - audio_jitter_output_accuracy: 0.7825 - val_loss: 2.0570 - val_video_packets_loss_output_loss: 0.3225 - val_audio_packets_loss_output_loss: 0.5642 - val_video_jitter_output_loss: 0.5353 - val_audio_jitter_output_loss: 0.5803 - val_video_packets_loss_output_accuracy: 0.8960 - val_audio_packets_loss_output_accuracy: 0.7930 - val_video_jitter_output_accuracy: 0.8023 - val_audio_jitter_output_accuracy: 0.7869
# Epoch 4/10
# 4824/4824 [==============================] - 19s 4ms/step - loss: 2.0529 - video_packets_loss_output_loss: 0.3181 - audio_packets_loss_output_loss: 0.5711 - video_jitter_output_loss: 0.5339 - audio_jitter_output_loss: 0.5742 - video_packets_loss_output_accuracy: 0.8969 - audio_packets_loss_output_accuracy: 0.7888 - video_jitter_output_accuracy: 0.8044 - audio_jitter_output_accuracy: 0.7855 - val_loss: 2.0539 - val_video_packets_loss_output_loss: 0.3191 - val_audio_packets_loss_output_loss: 0.5642 - val_video_jitter_output_loss: 0.5275 - val_audio_jitter_output_loss: 0.5873 - val_video_packets_loss_output_accuracy: 0.8963 - val_audio_packets_loss_output_accuracy: 0.7914 - val_video_jitter_output_accuracy: 0.8038 - val_audio_jitter_output_accuracy: 0.7844
# Epoch 5/10
# 4824/4824 [==============================] - 19s 4ms/step - loss: 2.0467 - video_packets_loss_output_loss: 0.3167 - audio_packets_loss_output_loss: 0.5675 - video_jitter_output_loss: 0.5355 - audio_jitter_output_loss: 0.5712 - video_packets_loss_output_accuracy: 0.8969 - audio_packets_loss_output_accuracy: 0.7894 - video_jitter_output_accuracy: 0.8047 - audio_jitter_output_accuracy: 0.7859 - val_loss: 2.0285 - val_video_packets_loss_output_loss: 0.3181 - val_audio_packets_loss_output_loss: 0.5592 - val_video_jitter_output_loss: 0.5165 - val_audio_jitter_output_loss: 0.5794 - val_video_packets_loss_output_accuracy: 0.8961 - val_audio_packets_loss_output_accuracy: 0.7921 - val_video_jitter_output_accuracy: 0.8112 - val_audio_jitter_output_accuracy: 0.7872
# Epoch 6/10
# 4824/4824 [==============================] - 19s 4ms/step - loss: 2.0310 - video_packets_loss_output_loss: 0.3171 - audio_packets_loss_output_loss: 0.5606 - video_jitter_output_loss: 0.5275 - audio_jitter_output_loss: 0.5700 - video_packets_loss_output_accuracy: 0.8968 - audio_packets_loss_output_accuracy: 0.7945 - video_jitter_output_accuracy: 0.8073 - audio_jitter_output_accuracy: 0.7866 - val_loss: 2.0427 - val_video_packets_loss_output_loss: 0.3180 - val_audio_packets_loss_output_loss: 0.5606 - val_video_jitter_output_loss: 0.5311 - val_audio_jitter_output_loss: 0.5782 - val_video_packets_loss_output_accuracy: 0.8969 - val_audio_packets_loss_output_accuracy: 0.7945 - val_video_jitter_output_accuracy: 0.8056 - val_audio_jitter_output_accuracy: 0.7879
# Epoch 7/10
# 4824/4824 [==============================] - 19s 4ms/step - loss: 2.0156 - video_packets_loss_output_loss: 0.3147 - audio_packets_loss_output_loss: 0.5543 - video_jitter_output_loss: 0.5253 - audio_jitter_output_loss: 0.5653 - video_packets_loss_output_accuracy: 0.8973 - audio_packets_loss_output_accuracy: 0.7962 - video_jitter_output_accuracy: 0.8074 - audio_jitter_output_accuracy: 0.7877 - val_loss: 2.0171 - val_video_packets_loss_output_loss: 0.3177 - val_audio_packets_loss_output_loss: 0.5463 - val_video_jitter_output_loss: 0.5210 - val_audio_jitter_output_loss: 0.5769 - val_video_packets_loss_output_accuracy: 0.8967 - val_audio_packets_loss_output_accuracy: 0.8014 - val_video_jitter_output_accuracy: 0.8101 - val_audio_jitter_output_accuracy: 0.7879
# Epoch 8/10
# 4824/4824 [==============================] - 19s 4ms/step - loss: 2.0049 - video_packets_loss_output_loss: 0.3137 - audio_packets_loss_output_loss: 0.5497 - video_jitter_output_loss: 0.5241 - audio_jitter_output_loss: 0.5611 - video_packets_loss_output_accuracy: 0.8974 - audio_packets_loss_output_accuracy: 0.7973 - video_jitter_output_accuracy: 0.8089 - audio_jitter_output_accuracy: 0.7897 - val_loss: 2.0311 - val_video_packets_loss_output_loss: 0.3178 - val_audio_packets_loss_output_loss: 0.5545 - val_video_jitter_output_loss: 0.5265 - val_audio_jitter_output_loss: 0.5763 - val_video_packets_loss_output_accuracy: 0.8963 - val_audio_packets_loss_output_accuracy: 0.7971 - val_video_jitter_output_accuracy: 0.8052 - val_audio_jitter_output_accuracy: 0.7873
# Epoch 9/10
# 4824/4824 [==============================] - 19s 4ms/step - loss: 1.9938 - video_packets_loss_output_loss: 0.3127 - audio_packets_loss_output_loss: 0.5456 - video_jitter_output_loss: 0.5208 - audio_jitter_output_loss: 0.5580 - video_packets_loss_output_accuracy: 0.8973 - audio_packets_loss_output_accuracy: 0.7997 - video_jitter_output_accuracy: 0.8090 - audio_jitter_output_accuracy: 0.7897 - val_loss: 1.9976 - val_video_packets_loss_output_loss: 0.3156 - val_audio_packets_loss_output_loss: 0.5469 - val_video_jitter_output_loss: 0.5138 - val_audio_jitter_output_loss: 0.5653 - val_video_packets_loss_output_accuracy: 0.8968 - val_audio_packets_loss_output_accuracy: 0.7980 - val_video_jitter_output_accuracy: 0.8122 - val_audio_jitter_output_accuracy: 0.7929
# Epoch 10/10
# 4824/4824 [==============================] - 19s 4ms/step - loss: 1.9841 - video_packets_loss_output_loss: 0.3128 - audio_packets_loss_output_loss: 0.5416 - video_jitter_output_loss: 0.5189 - audio_jitter_output_loss: 0.5537 - video_packets_loss_output_accuracy: 0.8974 - audio_packets_loss_output_accuracy: 0.8017 - video_jitter_output_accuracy: 0.8104 - audio_jitter_output_accuracy: 0.7916 - val_loss: 2.0334 - val_video_packets_loss_output_loss: 0.3180 - val_audio_packets_loss_output_loss: 0.5457 - val_video_jitter_output_loss: 0.5317 - val_audio_jitter_output_loss: 0.5813 - val_video_packets_loss_output_accuracy: 0.8970 - val_audio_packets_loss_output_accuracy: 0.8000 - val_video_jitter_output_accuracy: 0.8083 - val_audio_jitter_output_accuracy: 0.7893
#
#
#  ***** TRAINING 3
# Epoch 1/10
# 4824/4824 [==============================] - 19s 4ms/step - loss: 1.9715 - video_packets_loss_output_loss: 0.3115 - audio_packets_loss_output_loss: 0.5344 - video_jitter_output_loss: 0.5162 - audio_jitter_output_loss: 0.5522 - video_packets_loss_output_accuracy: 0.8975 - audio_packets_loss_output_accuracy: 0.8032 - video_jitter_output_accuracy: 0.8121 - audio_jitter_output_accuracy: 0.7915 - val_loss: 1.9822 - val_video_packets_loss_output_loss: 0.3118 - val_audio_packets_loss_output_loss: 0.5400 - val_video_jitter_output_loss: 0.5136 - val_audio_jitter_output_loss: 0.5607 - val_video_packets_loss_output_accuracy: 0.8968 - val_audio_packets_loss_output_accuracy: 0.8046 - val_video_jitter_output_accuracy: 0.8145 - val_audio_jitter_output_accuracy: 0.7939
# Epoch 2/10
# 4824/4824 [==============================] - 19s 4ms/step - loss: 1.9637 - video_packets_loss_output_loss: 0.3109 - audio_packets_loss_output_loss: 0.5340 - video_jitter_output_loss: 0.5131 - audio_jitter_output_loss: 0.5486 - video_packets_loss_output_accuracy: 0.8977 - audio_packets_loss_output_accuracy: 0.8052 - video_jitter_output_accuracy: 0.8123 - audio_jitter_output_accuracy: 0.7929 - val_loss: 1.9940 - val_video_packets_loss_output_loss: 0.3110 - val_audio_packets_loss_output_loss: 0.5418 - val_video_jitter_output_loss: 0.5137 - val_audio_jitter_output_loss: 0.5712 - val_video_packets_loss_output_accuracy: 0.8976 - val_audio_packets_loss_output_accuracy: 0.8040 - val_video_jitter_output_accuracy: 0.8133 - val_audio_jitter_output_accuracy: 0.7888
# Epoch 3/10
# 4824/4824 [==============================] - 19s 4ms/step - loss: 1.9500 - video_packets_loss_output_loss: 0.3097 - audio_packets_loss_output_loss: 0.5290 - video_jitter_output_loss: 0.5114 - audio_jitter_output_loss: 0.5424 - video_packets_loss_output_accuracy: 0.8979 - audio_packets_loss_output_accuracy: 0.8066 - video_jitter_output_accuracy: 0.8132 - audio_jitter_output_accuracy: 0.7945 - val_loss: 1.9839 - val_video_packets_loss_output_loss: 0.3143 - val_audio_packets_loss_output_loss: 0.5372 - val_video_jitter_output_loss: 0.5089 - val_audio_jitter_output_loss: 0.5670 - val_video_packets_loss_output_accuracy: 0.8970 - val_audio_packets_loss_output_accuracy: 0.8038 - val_video_jitter_output_accuracy: 0.8119 - val_audio_jitter_output_accuracy: 0.7947
# Epoch 4/10
# 4824/4824 [==============================] - 19s 4ms/step - loss: 1.9488 - video_packets_loss_output_loss: 0.3078 - audio_packets_loss_output_loss: 0.5292 - video_jitter_output_loss: 0.5111 - audio_jitter_output_loss: 0.5432 - video_packets_loss_output_accuracy: 0.8985 - audio_packets_loss_output_accuracy: 0.8063 - video_jitter_output_accuracy: 0.8135 - audio_jitter_output_accuracy: 0.7953 - val_loss: 1.9870 - val_video_packets_loss_output_loss: 0.3153 - val_audio_packets_loss_output_loss: 0.5381 - val_video_jitter_output_loss: 0.5109 - val_audio_jitter_output_loss: 0.5663 - val_video_packets_loss_output_accuracy: 0.8976 - val_audio_packets_loss_output_accuracy: 0.8012 - val_video_jitter_output_accuracy: 0.8125 - val_audio_jitter_output_accuracy: 0.7904
# Epoch 5/10
# 4824/4824 [==============================] - 21s 4ms/step - loss: 1.9365 - video_packets_loss_output_loss: 0.3069 - audio_packets_loss_output_loss: 0.5248 - video_jitter_output_loss: 0.5073 - audio_jitter_output_loss: 0.5399 - video_packets_loss_output_accuracy: 0.8984 - audio_packets_loss_output_accuracy: 0.8082 - video_jitter_output_accuracy: 0.8137 - audio_jitter_output_accuracy: 0.7958 - val_loss: 1.9978 - val_video_packets_loss_output_loss: 0.3123 - val_audio_packets_loss_output_loss: 0.5378 - val_video_jitter_output_loss: 0.5151 - val_audio_jitter_output_loss: 0.5754 - val_video_packets_loss_output_accuracy: 0.8976 - val_audio_packets_loss_output_accuracy: 0.8043 - val_video_jitter_output_accuracy: 0.8150 - val_audio_jitter_output_accuracy: 0.7928
# Epoch 6/10
# 4824/4824 [==============================] - 21s 4ms/step - loss: 1.9271 - video_packets_loss_output_loss: 0.3064 - audio_packets_loss_output_loss: 0.5191 - video_jitter_output_loss: 0.5061 - audio_jitter_output_loss: 0.5378 - video_packets_loss_output_accuracy: 0.8981 - audio_packets_loss_output_accuracy: 0.8103 - video_jitter_output_accuracy: 0.8147 - audio_jitter_output_accuracy: 0.7957 - val_loss: 1.9622 - val_video_packets_loss_output_loss: 0.3089 - val_audio_packets_loss_output_loss: 0.5314 - val_video_jitter_output_loss: 0.5044 - val_audio_jitter_output_loss: 0.5602 - val_video_packets_loss_output_accuracy: 0.8986 - val_audio_packets_loss_output_accuracy: 0.8066 - val_video_jitter_output_accuracy: 0.8169 - val_audio_jitter_output_accuracy: 0.7944
# Epoch 7/10
# 4824/4824 [==============================] - 21s 4ms/step - loss: 1.9223 - video_packets_loss_output_loss: 0.3061 - audio_packets_loss_output_loss: 0.5177 - video_jitter_output_loss: 0.5030 - audio_jitter_output_loss: 0.5379 - video_packets_loss_output_accuracy: 0.8986 - audio_packets_loss_output_accuracy: 0.8125 - video_jitter_output_accuracy: 0.8151 - audio_jitter_output_accuracy: 0.7969 - val_loss: 1.9746 - val_video_packets_loss_output_loss: 0.3113 - val_audio_packets_loss_output_loss: 0.5292 - val_video_jitter_output_loss: 0.5106 - val_audio_jitter_output_loss: 0.5660 - val_video_packets_loss_output_accuracy: 0.8976 - val_audio_packets_loss_output_accuracy: 0.8076 - val_video_jitter_output_accuracy: 0.8138 - val_audio_jitter_output_accuracy: 0.7938
# Epoch 8/10
# 4824/4824 [==============================] - 21s 4ms/step - loss: 1.9120 - video_packets_loss_output_loss: 0.3050 - audio_packets_loss_output_loss: 0.5114 - video_jitter_output_loss: 0.5012 - audio_jitter_output_loss: 0.5360 - video_packets_loss_output_accuracy: 0.8990 - audio_packets_loss_output_accuracy: 0.8137 - video_jitter_output_accuracy: 0.8161 - audio_jitter_output_accuracy: 0.7973 - val_loss: 1.9422 - val_video_packets_loss_output_loss: 0.3060 - val_audio_packets_loss_output_loss: 0.5199 - val_video_jitter_output_loss: 0.4980 - val_audio_jitter_output_loss: 0.5604 - val_video_packets_loss_output_accuracy: 0.9007 - val_audio_packets_loss_output_accuracy: 0.8126 - val_video_jitter_output_accuracy: 0.8188 - val_audio_jitter_output_accuracy: 0.7930
# Epoch 9/10
# 4824/4824 [==============================] - 21s 4ms/step - loss: 1.9073 - video_packets_loss_output_loss: 0.3043 - audio_packets_loss_output_loss: 0.5106 - video_jitter_output_loss: 0.5011 - audio_jitter_output_loss: 0.5326 - video_packets_loss_output_accuracy: 0.8987 - audio_packets_loss_output_accuracy: 0.8148 - video_jitter_output_accuracy: 0.8155 - audio_jitter_output_accuracy: 0.7989 - val_loss: 1.9450 - val_video_packets_loss_output_loss: 0.3026 - val_audio_packets_loss_output_loss: 0.5192 - val_video_jitter_output_loss: 0.5083 - val_audio_jitter_output_loss: 0.5570 - val_video_packets_loss_output_accuracy: 0.8996 - val_audio_packets_loss_output_accuracy: 0.8119 - val_video_jitter_output_accuracy: 0.8146 - val_audio_jitter_output_accuracy: 0.7974
# Epoch 10/10
# 4824/4824 [==============================] - 22s 5ms/step - loss: 1.8962 - video_packets_loss_output_loss: 0.3014 - audio_packets_loss_output_loss: 0.5090 - video_jitter_output_loss: 0.4958 - audio_jitter_output_loss: 0.5313 - video_packets_loss_output_accuracy: 0.8995 - audio_packets_loss_output_accuracy: 0.8149 - video_jitter_output_accuracy: 0.8172 - audio_jitter_output_accuracy: 0.7993 - val_loss: 1.9546 - val_video_packets_loss_output_loss: 0.3077 - val_audio_packets_loss_output_loss: 0.5220 - val_video_jitter_output_loss: 0.5073 - val_audio_jitter_output_loss: 0.5596 - val_video_packets_loss_output_accuracy: 0.8985 - val_audio_packets_loss_output_accuracy: 0.8123 - val_video_jitter_output_accuracy: 0.8174 - val_audio_jitter_output_accuracy: 0.7931
#
#
#  ***** TRAINING 4
# Epoch 1/10
# 4824/4824 [==============================] - 21s 4ms/step - loss: 1.8929 - video_packets_loss_output_loss: 0.3021 - audio_packets_loss_output_loss: 0.5061 - video_jitter_output_loss: 0.4954 - audio_jitter_output_loss: 0.5306 - video_packets_loss_output_accuracy: 0.8997 - audio_packets_loss_output_accuracy: 0.8170 - video_jitter_output_accuracy: 0.8175 - audio_jitter_output_accuracy: 0.7991 - val_loss: 1.9363 - val_video_packets_loss_output_loss: 0.3046 - val_audio_packets_loss_output_loss: 0.5212 - val_video_jitter_output_loss: 0.4991 - val_audio_jitter_output_loss: 0.5532 - val_video_packets_loss_output_accuracy: 0.8998 - val_audio_packets_loss_output_accuracy: 0.8145 - val_video_jitter_output_accuracy: 0.8192 - val_audio_jitter_output_accuracy: 0.7977
# Epoch 2/10
# 4824/4824 [==============================] - 20s 4ms/step - loss: 1.8845 - video_packets_loss_output_loss: 0.3012 - audio_packets_loss_output_loss: 0.5039 - video_jitter_output_loss: 0.4941 - audio_jitter_output_loss: 0.5264 - video_packets_loss_output_accuracy: 0.8999 - audio_packets_loss_output_accuracy: 0.8174 - video_jitter_output_accuracy: 0.8185 - audio_jitter_output_accuracy: 0.8004 - val_loss: 1.9418 - val_video_packets_loss_output_loss: 0.3048 - val_audio_packets_loss_output_loss: 0.5210 - val_video_jitter_output_loss: 0.5024 - val_audio_jitter_output_loss: 0.5541 - val_video_packets_loss_output_accuracy: 0.8990 - val_audio_packets_loss_output_accuracy: 0.8133 - val_video_jitter_output_accuracy: 0.8152 - val_audio_jitter_output_accuracy: 0.7980
# Epoch 3/10
# 4824/4824 [==============================] - 20s 4ms/step - loss: 1.8786 - video_packets_loss_output_loss: 0.3001 - audio_packets_loss_output_loss: 0.5022 - video_jitter_output_loss: 0.4914 - audio_jitter_output_loss: 0.5255 - video_packets_loss_output_accuracy: 0.8998 - audio_packets_loss_output_accuracy: 0.8182 - video_jitter_output_accuracy: 0.8189 - audio_jitter_output_accuracy: 0.8007 - val_loss: 1.9187 - val_video_packets_loss_output_loss: 0.3040 - val_audio_packets_loss_output_loss: 0.5115 - val_video_jitter_output_loss: 0.4946 - val_audio_jitter_output_loss: 0.5511 - val_video_packets_loss_output_accuracy: 0.8994 - val_audio_packets_loss_output_accuracy: 0.8161 - val_video_jitter_output_accuracy: 0.8209 - val_audio_jitter_output_accuracy: 0.7985
# Epoch 4/10
# 4824/4824 [==============================] - 19s 4ms/step - loss: 1.8672 - video_packets_loss_output_loss: 0.2994 - audio_packets_loss_output_loss: 0.4964 - video_jitter_output_loss: 0.4887 - audio_jitter_output_loss: 0.5238 - video_packets_loss_output_accuracy: 0.9006 - audio_packets_loss_output_accuracy: 0.8199 - video_jitter_output_accuracy: 0.8190 - audio_jitter_output_accuracy: 0.8019 - val_loss: 1.9395 - val_video_packets_loss_output_loss: 0.3032 - val_audio_packets_loss_output_loss: 0.5173 - val_video_jitter_output_loss: 0.4986 - val_audio_jitter_output_loss: 0.5611 - val_video_packets_loss_output_accuracy: 0.9002 - val_audio_packets_loss_output_accuracy: 0.8139 - val_video_jitter_output_accuracy: 0.8184 - val_audio_jitter_output_accuracy: 0.7952
# Epoch 5/10
# 4824/4824 [==============================] - 19s 4ms/step - loss: 1.8677 - video_packets_loss_output_loss: 0.2983 - audio_packets_loss_output_loss: 0.4985 - video_jitter_output_loss: 0.4868 - audio_jitter_output_loss: 0.5248 - video_packets_loss_output_accuracy: 0.9003 - audio_packets_loss_output_accuracy: 0.8197 - video_jitter_output_accuracy: 0.8212 - audio_jitter_output_accuracy: 0.8005 - val_loss: 1.9253 - val_video_packets_loss_output_loss: 0.2998 - val_audio_packets_loss_output_loss: 0.5164 - val_video_jitter_output_loss: 0.4963 - val_audio_jitter_output_loss: 0.5546 - val_video_packets_loss_output_accuracy: 0.8995 - val_audio_packets_loss_output_accuracy: 0.8143 - val_video_jitter_output_accuracy: 0.8192 - val_audio_jitter_output_accuracy: 0.7950
# Epoch 6/10
# 4824/4824 [==============================] - 20s 4ms/step - loss: 1.8653 - video_packets_loss_output_loss: 0.2961 - audio_packets_loss_output_loss: 0.4977 - video_jitter_output_loss: 0.4892 - audio_jitter_output_loss: 0.5230 - video_packets_loss_output_accuracy: 0.9017 - audio_packets_loss_output_accuracy: 0.8195 - video_jitter_output_accuracy: 0.8206 - audio_jitter_output_accuracy: 0.8019 - val_loss: 1.9365 - val_video_packets_loss_output_loss: 0.3032 - val_audio_packets_loss_output_loss: 0.5259 - val_video_jitter_output_loss: 0.4997 - val_audio_jitter_output_loss: 0.5488 - val_video_packets_loss_output_accuracy: 0.9011 - val_audio_packets_loss_output_accuracy: 0.8140 - val_video_jitter_output_accuracy: 0.8192 - val_audio_jitter_output_accuracy: 0.7990
# Epoch 7/10
# 4824/4824 [==============================] - 19s 4ms/step - loss: 1.8539 - video_packets_loss_output_loss: 0.2965 - audio_packets_loss_output_loss: 0.4915 - video_jitter_output_loss: 0.4861 - audio_jitter_output_loss: 0.5205 - video_packets_loss_output_accuracy: 0.9015 - audio_packets_loss_output_accuracy: 0.8220 - video_jitter_output_accuracy: 0.8216 - audio_jitter_output_accuracy: 0.8025 - val_loss: 1.9169 - val_video_packets_loss_output_loss: 0.3029 - val_audio_packets_loss_output_loss: 0.5151 - val_video_jitter_output_loss: 0.4947 - val_audio_jitter_output_loss: 0.5457 - val_video_packets_loss_output_accuracy: 0.9008 - val_audio_packets_loss_output_accuracy: 0.8163 - val_video_jitter_output_accuracy: 0.8220 - val_audio_jitter_output_accuracy: 0.8020
# Epoch 8/10
# 4824/4824 [==============================] - 21s 4ms/step - loss: 1.8539 - video_packets_loss_output_loss: 0.2962 - audio_packets_loss_output_loss: 0.4918 - video_jitter_output_loss: 0.4838 - audio_jitter_output_loss: 0.5227 - video_packets_loss_output_accuracy: 0.9017 - audio_packets_loss_output_accuracy: 0.8214 - video_jitter_output_accuracy: 0.8217 - audio_jitter_output_accuracy: 0.8015 - val_loss: 1.9264 - val_video_packets_loss_output_loss: 0.3018 - val_audio_packets_loss_output_loss: 0.5129 - val_video_jitter_output_loss: 0.5005 - val_audio_jitter_output_loss: 0.5518 - val_video_packets_loss_output_accuracy: 0.9020 - val_audio_packets_loss_output_accuracy: 0.8181 - val_video_jitter_output_accuracy: 0.8186 - val_audio_jitter_output_accuracy: 0.7987
# Epoch 9/10
# 4824/4824 [==============================] - 21s 4ms/step - loss: 1.8465 - video_packets_loss_output_loss: 0.2954 - audio_packets_loss_output_loss: 0.4895 - video_jitter_output_loss: 0.4827 - audio_jitter_output_loss: 0.5189 - video_packets_loss_output_accuracy: 0.9019 - audio_packets_loss_output_accuracy: 0.8240 - video_jitter_output_accuracy: 0.8220 - audio_jitter_output_accuracy: 0.8026 - val_loss: 1.9284 - val_video_packets_loss_output_loss: 0.3012 - val_audio_packets_loss_output_loss: 0.5171 - val_video_jitter_output_loss: 0.4938 - val_audio_jitter_output_loss: 0.5573 - val_video_packets_loss_output_accuracy: 0.9029 - val_audio_packets_loss_output_accuracy: 0.8165 - val_video_jitter_output_accuracy: 0.8243 - val_audio_jitter_output_accuracy: 0.7964
# Epoch 10/10
# 4824/4824 [==============================] - 21s 4ms/step - loss: 1.8450 - video_packets_loss_output_loss: 0.2948 - audio_packets_loss_output_loss: 0.4888 - video_jitter_output_loss: 0.4833 - audio_jitter_output_loss: 0.5181 - video_packets_loss_output_accuracy: 0.9027 - audio_packets_loss_output_accuracy: 0.8227 - video_jitter_output_accuracy: 0.8217 - audio_jitter_output_accuracy: 0.8032 - val_loss: 1.9178 - val_video_packets_loss_output_loss: 0.2962 - val_audio_packets_loss_output_loss: 0.5136 - val_video_jitter_output_loss: 0.4933 - val_audio_jitter_output_loss: 0.5552 - val_video_packets_loss_output_accuracy: 0.9025 - val_audio_packets_loss_output_accuracy: 0.8159 - val_video_jitter_output_accuracy: 0.8197 - val_audio_jitter_output_accuracy: 0.7985
#
#
#  ***** TRAINING 5
# Epoch 1/10
# 4824/4824 [==============================] - 21s 4ms/step - loss: 1.8357 - video_packets_loss_output_loss: 0.2929 - audio_packets_loss_output_loss: 0.4870 - video_jitter_output_loss: 0.4799 - audio_jitter_output_loss: 0.5158 - video_packets_loss_output_accuracy: 0.9026 - audio_packets_loss_output_accuracy: 0.8240 - video_jitter_output_accuracy: 0.8233 - audio_jitter_output_accuracy: 0.8032 - val_loss: 1.9008 - val_video_packets_loss_output_loss: 0.2996 - val_audio_packets_loss_output_loss: 0.5067 - val_video_jitter_output_loss: 0.4896 - val_audio_jitter_output_loss: 0.5451 - val_video_packets_loss_output_accuracy: 0.9014 - val_audio_packets_loss_output_accuracy: 0.8194 - val_video_jitter_output_accuracy: 0.8230 - val_audio_jitter_output_accuracy: 0.8032
# Epoch 2/10
# 4824/4824 [==============================] - 21s 4ms/step - loss: 1.8340 - video_packets_loss_output_loss: 0.2925 - audio_packets_loss_output_loss: 0.4856 - video_jitter_output_loss: 0.4796 - audio_jitter_output_loss: 0.5167 - video_packets_loss_output_accuracy: 0.9034 - audio_packets_loss_output_accuracy: 0.8257 - video_jitter_output_accuracy: 0.8232 - audio_jitter_output_accuracy: 0.8032 - val_loss: 1.8980 - val_video_packets_loss_output_loss: 0.2964 - val_audio_packets_loss_output_loss: 0.5003 - val_video_jitter_output_loss: 0.4962 - val_audio_jitter_output_loss: 0.5454 - val_video_packets_loss_output_accuracy: 0.9025 - val_audio_packets_loss_output_accuracy: 0.8244 - val_video_jitter_output_accuracy: 0.8205 - val_audio_jitter_output_accuracy: 0.8012
# Epoch 3/10
# 4824/4824 [==============================] - 20s 4ms/step - loss: 1.8274 - video_packets_loss_output_loss: 0.2915 - audio_packets_loss_output_loss: 0.4827 - video_jitter_output_loss: 0.4792 - audio_jitter_output_loss: 0.5138 - video_packets_loss_output_accuracy: 0.9035 - audio_packets_loss_output_accuracy: 0.8260 - video_jitter_output_accuracy: 0.8239 - audio_jitter_output_accuracy: 0.8046 - val_loss: 1.9035 - val_video_packets_loss_output_loss: 0.2937 - val_audio_packets_loss_output_loss: 0.5017 - val_video_jitter_output_loss: 0.4900 - val_audio_jitter_output_loss: 0.5574 - val_video_packets_loss_output_accuracy: 0.9042 - val_audio_packets_loss_output_accuracy: 0.8202 - val_video_jitter_output_accuracy: 0.8242 - val_audio_jitter_output_accuracy: 0.7985
# Epoch 4/10
# 4824/4824 [==============================] - 19s 4ms/step - loss: 1.8255 - video_packets_loss_output_loss: 0.2916 - audio_packets_loss_output_loss: 0.4851 - video_jitter_output_loss: 0.4755 - audio_jitter_output_loss: 0.5130 - video_packets_loss_output_accuracy: 0.9035 - audio_packets_loss_output_accuracy: 0.8258 - video_jitter_output_accuracy: 0.8251 - audio_jitter_output_accuracy: 0.8062 - val_loss: 1.9115 - val_video_packets_loss_output_loss: 0.2947 - val_audio_packets_loss_output_loss: 0.5134 - val_video_jitter_output_loss: 0.4858 - val_audio_jitter_output_loss: 0.5579 - val_video_packets_loss_output_accuracy: 0.9021 - val_audio_packets_loss_output_accuracy: 0.8170 - val_video_jitter_output_accuracy: 0.8240 - val_audio_jitter_output_accuracy: 0.7962
# Epoch 5/10
# 4824/4824 [==============================] - 20s 4ms/step - loss: 1.8212 - video_packets_loss_output_loss: 0.2892 - audio_packets_loss_output_loss: 0.4816 - video_jitter_output_loss: 0.4768 - audio_jitter_output_loss: 0.5126 - video_packets_loss_output_accuracy: 0.9044 - audio_packets_loss_output_accuracy: 0.8268 - video_jitter_output_accuracy: 0.8250 - audio_jitter_output_accuracy: 0.8048 - val_loss: 1.8844 - val_video_packets_loss_output_loss: 0.2933 - val_audio_packets_loss_output_loss: 0.5000 - val_video_jitter_output_loss: 0.4855 - val_audio_jitter_output_loss: 0.5453 - val_video_packets_loss_output_accuracy: 0.9031 - val_audio_packets_loss_output_accuracy: 0.8240 - val_video_jitter_output_accuracy: 0.8243 - val_audio_jitter_output_accuracy: 0.8035
# Epoch 6/10
# 4824/4824 [==============================] - 20s 4ms/step - loss: 1.8212 - video_packets_loss_output_loss: 0.2890 - audio_packets_loss_output_loss: 0.4835 - video_jitter_output_loss: 0.4753 - audio_jitter_output_loss: 0.5132 - video_packets_loss_output_accuracy: 0.9043 - audio_packets_loss_output_accuracy: 0.8260 - video_jitter_output_accuracy: 0.8249 - audio_jitter_output_accuracy: 0.8040 - val_loss: 1.8794 - val_video_packets_loss_output_loss: 0.2903 - val_audio_packets_loss_output_loss: 0.5019 - val_video_jitter_output_loss: 0.4859 - val_audio_jitter_output_loss: 0.5417 - val_video_packets_loss_output_accuracy: 0.9069 - val_audio_packets_loss_output_accuracy: 0.8235 - val_video_jitter_output_accuracy: 0.8269 - val_audio_jitter_output_accuracy: 0.8030
# Epoch 7/10
# 4824/4824 [==============================] - 19s 4ms/step - loss: 1.8120 - video_packets_loss_output_loss: 0.2870 - audio_packets_loss_output_loss: 0.4779 - video_jitter_output_loss: 0.4744 - audio_jitter_output_loss: 0.5117 - video_packets_loss_output_accuracy: 0.9048 - audio_packets_loss_output_accuracy: 0.8287 - video_jitter_output_accuracy: 0.8252 - audio_jitter_output_accuracy: 0.8055 - val_loss: 1.8745 - val_video_packets_loss_output_loss: 0.2895 - val_audio_packets_loss_output_loss: 0.5059 - val_video_jitter_output_loss: 0.4846 - val_audio_jitter_output_loss: 0.5353 - val_video_packets_loss_output_accuracy: 0.9055 - val_audio_packets_loss_output_accuracy: 0.8225 - val_video_jitter_output_accuracy: 0.8270 - val_audio_jitter_output_accuracy: 0.8055
# Epoch 8/10
# 4824/4824 [==============================] - 19s 4ms/step - loss: 1.8061 - video_packets_loss_output_loss: 0.2874 - audio_packets_loss_output_loss: 0.4758 - video_jitter_output_loss: 0.4727 - audio_jitter_output_loss: 0.5095 - video_packets_loss_output_accuracy: 0.9053 - audio_packets_loss_output_accuracy: 0.8299 - video_jitter_output_accuracy: 0.8258 - audio_jitter_output_accuracy: 0.8068 - val_loss: 1.8776 - val_video_packets_loss_output_loss: 0.2911 - val_audio_packets_loss_output_loss: 0.5053 - val_video_jitter_output_loss: 0.4832 - val_audio_jitter_output_loss: 0.5377 - val_video_packets_loss_output_accuracy: 0.9054 - val_audio_packets_loss_output_accuracy: 0.8203 - val_video_jitter_output_accuracy: 0.8215 - val_audio_jitter_output_accuracy: 0.8022
# Epoch 9/10
# 4824/4824 [==============================] - 19s 4ms/step - loss: 1.8031 - video_packets_loss_output_loss: 0.2852 - audio_packets_loss_output_loss: 0.4749 - video_jitter_output_loss: 0.4723 - audio_jitter_output_loss: 0.5097 - video_packets_loss_output_accuracy: 0.9055 - audio_packets_loss_output_accuracy: 0.8295 - video_jitter_output_accuracy: 0.8267 - audio_jitter_output_accuracy: 0.8050 - val_loss: 1.8888 - val_video_packets_loss_output_loss: 0.2884 - val_audio_packets_loss_output_loss: 0.5043 - val_video_jitter_output_loss: 0.4888 - val_audio_jitter_output_loss: 0.5459 - val_video_packets_loss_output_accuracy: 0.9077 - val_audio_packets_loss_output_accuracy: 0.8205 - val_video_jitter_output_accuracy: 0.8245 - val_audio_jitter_output_accuracy: 0.8015
# Epoch 10/10
# 4824/4824 [==============================] - 19s 4ms/step - loss: 1.8021 - video_packets_loss_output_loss: 0.2862 - audio_packets_loss_output_loss: 0.4730 - video_jitter_output_loss: 0.4721 - audio_jitter_output_loss: 0.5093 - video_packets_loss_output_accuracy: 0.9050 - audio_packets_loss_output_accuracy: 0.8307 - video_jitter_output_accuracy: 0.8264 - audio_jitter_output_accuracy: 0.8051 - val_loss: 1.9107 - val_video_packets_loss_output_loss: 0.2905 - val_audio_packets_loss_output_loss: 0.4998 - val_video_jitter_output_loss: 0.4985 - val_audio_jitter_output_loss: 0.5611 - val_video_packets_loss_output_accuracy: 0.9060 - val_audio_packets_loss_output_accuracy: 0.8223 - val_video_jitter_output_accuracy: 0.8211 - val_audio_jitter_output_accuracy: 0.7979
#
#
#  ***** TRAINING 6
# Epoch 1/10
# 4824/4824 [==============================] - 19s 4ms/step - loss: 1.7985 - video_packets_loss_output_loss: 0.2843 - audio_packets_loss_output_loss: 0.4731 - video_jitter_output_loss: 0.4712 - audio_jitter_output_loss: 0.5088 - video_packets_loss_output_accuracy: 0.9057 - audio_packets_loss_output_accuracy: 0.8315 - video_jitter_output_accuracy: 0.8267 - audio_jitter_output_accuracy: 0.8062 - val_loss: 1.8738 - val_video_packets_loss_output_loss: 0.2894 - val_audio_packets_loss_output_loss: 0.4953 - val_video_jitter_output_loss: 0.4887 - val_audio_jitter_output_loss: 0.5395 - val_video_packets_loss_output_accuracy: 0.9060 - val_audio_packets_loss_output_accuracy: 0.8248 - val_video_jitter_output_accuracy: 0.8225 - val_audio_jitter_output_accuracy: 0.8030
# Epoch 2/10
# ...
#
#
#  ***** TRAINING 8
# Epoch 1/10
# 4824/4824 [==============================] - 19s 4ms/step - loss: 1.7420 - video_packets_loss_output_loss: 0.2723 - audio_packets_loss_output_loss: 0.4561 - video_jitter_output_loss: 0.4556 - audio_jitter_output_loss: 0.4950 - video_packets_loss_output_accuracy: 0.9105 - audio_packets_loss_output_accuracy: 0.8380 - video_jitter_output_accuracy: 0.8321 - audio_jitter_output_accuracy: 0.8096 - val_loss: 1.8457 - val_video_packets_loss_output_loss: 0.2838 - val_audio_packets_loss_output_loss: 0.4913 - val_video_jitter_output_loss: 0.4751 - val_audio_jitter_output_loss: 0.5328 - val_video_packets_loss_output_accuracy: 0.9106 - val_audio_packets_loss_output_accuracy: 0.8290 - val_video_jitter_output_accuracy: 0.8315 - val_audio_jitter_output_accuracy: 0.8080
# Epoch 2/10
# 4824/4824 [==============================] - 19s 4ms/step - loss: 1.7429 - video_packets_loss_output_loss: 0.2722 - audio_packets_loss_output_loss: 0.4553 - video_jitter_output_loss: 0.4572 - audio_jitter_output_loss: 0.4953 - video_packets_loss_output_accuracy: 0.9107 - audio_packets_loss_output_accuracy: 0.8385 - video_jitter_output_accuracy: 0.8324 - audio_jitter_output_accuracy: 0.8096 - val_loss: 1.8175 - val_video_packets_loss_output_loss: 0.2790 - val_audio_packets_loss_output_loss: 0.4805 - val_video_jitter_output_loss: 0.4694 - val_audio_jitter_output_loss: 0.5269 - val_video_packets_loss_output_accuracy: 0.9090 - val_audio_packets_loss_output_accuracy: 0.8342 - val_video_jitter_output_accuracy: 0.8322 - val_audio_jitter_output_accuracy: 0.8086
# Epoch 3/10
# 4824/4824 [==============================] - 19s 4ms/step - loss: 1.7357 - video_packets_loss_output_loss: 0.2700 - audio_packets_loss_output_loss: 0.4524 - video_jitter_output_loss: 0.4553 - audio_jitter_output_loss: 0.4951 - video_packets_loss_output_accuracy: 0.9107 - audio_packets_loss_output_accuracy: 0.8389 - video_jitter_output_accuracy: 0.8323 - audio_jitter_output_accuracy: 0.8111 - val_loss: 1.8407 - val_video_packets_loss_output_loss: 0.2771 - val_audio_packets_loss_output_loss: 0.4917 - val_video_jitter_output_loss: 0.4725 - val_audio_jitter_output_loss: 0.5363 - val_video_packets_loss_output_accuracy: 0.9128 - val_audio_packets_loss_output_accuracy: 0.8332 - val_video_jitter_output_accuracy: 0.8310 - val_audio_jitter_output_accuracy: 0.8062
# Epoch 4/10
# 4824/4824 [==============================] - 19s 4ms/step - loss: 1.7330 - video_packets_loss_output_loss: 0.2702 - audio_packets_loss_output_loss: 0.4502 - video_jitter_output_loss: 0.4549 - audio_jitter_output_loss: 0.4947 - video_packets_loss_output_accuracy: 0.9114 - audio_packets_loss_output_accuracy: 0.8406 - video_jitter_output_accuracy: 0.8322 - audio_jitter_output_accuracy: 0.8096 - val_loss: 1.8447 - val_video_packets_loss_output_loss: 0.2775 - val_audio_packets_loss_output_loss: 0.4906 - val_video_jitter_output_loss: 0.4730 - val_audio_jitter_output_loss: 0.5400 - val_video_packets_loss_output_accuracy: 0.9114 - val_audio_packets_loss_output_accuracy: 0.8316 - val_video_jitter_output_accuracy: 0.8302 - val_audio_jitter_output_accuracy: 0.8065
# Epoch 5/10
# 4824/4824 [==============================] - 19s 4ms/step - loss: 1.7335 - video_packets_loss_output_loss: 0.2706 - audio_packets_loss_output_loss: 0.4530 - video_jitter_output_loss: 0.4535 - audio_jitter_output_loss: 0.4935 - video_packets_loss_output_accuracy: 0.9108 - audio_packets_loss_output_accuracy: 0.8388 - video_jitter_output_accuracy: 0.8327 - audio_jitter_output_accuracy: 0.8108 - val_loss: 1.8788 - val_video_packets_loss_output_loss: 0.2839 - val_audio_packets_loss_output_loss: 0.5080 - val_video_jitter_output_loss: 0.4810 - val_audio_jitter_output_loss: 0.5437 - val_video_packets_loss_output_accuracy: 0.9121 - val_audio_packets_loss_output_accuracy: 0.8283 - val_video_jitter_output_accuracy: 0.8286 - val_audio_jitter_output_accuracy: 0.8029
# Epoch 6/10
# 4824/4824 [==============================] - 20s 4ms/step - loss: 1.7323 - video_packets_loss_output_loss: 0.2694 - audio_packets_loss_output_loss: 0.4520 - video_jitter_output_loss: 0.4542 - audio_jitter_output_loss: 0.4938 - video_packets_loss_output_accuracy: 0.9110 - audio_packets_loss_output_accuracy: 0.8407 - video_jitter_output_accuracy: 0.8328 - audio_jitter_output_accuracy: 0.8097 - val_loss: 1.8439 - val_video_packets_loss_output_loss: 0.2766 - val_audio_packets_loss_output_loss: 0.4841 - val_video_jitter_output_loss: 0.4770 - val_audio_jitter_output_loss: 0.5443 - val_video_packets_loss_output_accuracy: 0.9075 - val_audio_packets_loss_output_accuracy: 0.8321 - val_video_jitter_output_accuracy: 0.8272 - val_audio_jitter_output_accuracy: 0.8031
# Epoch 7/10
# 4824/4824 [==============================] - 19s 4ms/step - loss: 1.7261 - video_packets_loss_output_loss: 0.2699 - audio_packets_loss_output_loss: 0.4479 - video_jitter_output_loss: 0.4537 - audio_jitter_output_loss: 0.4912 - video_packets_loss_output_accuracy: 0.9112 - audio_packets_loss_output_accuracy: 0.8434 - video_jitter_output_accuracy: 0.8333 - audio_jitter_output_accuracy: 0.8108 - val_loss: 1.8513 - val_video_packets_loss_output_loss: 0.2767 - val_audio_packets_loss_output_loss: 0.4881 - val_video_jitter_output_loss: 0.4799 - val_audio_jitter_output_loss: 0.5451 - val_video_packets_loss_output_accuracy: 0.9101 - val_audio_packets_loss_output_accuracy: 0.8272 - val_video_jitter_output_accuracy: 0.8282 - val_audio_jitter_output_accuracy: 0.8042
# Epoch 8/10
# 4824/4824 [==============================] - 19s 4ms/step - loss: 1.7276 - video_packets_loss_output_loss: 0.2681 - audio_packets_loss_output_loss: 0.4499 - video_jitter_output_loss: 0.4539 - audio_jitter_output_loss: 0.4922 - video_packets_loss_output_accuracy: 0.9118 - audio_packets_loss_output_accuracy: 0.8405 - video_jitter_output_accuracy: 0.8327 - audio_jitter_output_accuracy: 0.8110 - val_loss: 1.8466 - val_video_packets_loss_output_loss: 0.2752 - val_audio_packets_loss_output_loss: 0.4846 - val_video_jitter_output_loss: 0.4808 - val_audio_jitter_output_loss: 0.5432 - val_video_packets_loss_output_accuracy: 0.9101 - val_audio_packets_loss_output_accuracy: 0.8331 - val_video_jitter_output_accuracy: 0.8258 - val_audio_jitter_output_accuracy: 0.8005
# Epoch 9/10
# 4824/4824 [==============================] - 19s 4ms/step - loss: 1.7229 - video_packets_loss_output_loss: 0.2668 - audio_packets_loss_output_loss: 0.4491 - video_jitter_output_loss: 0.4527 - audio_jitter_output_loss: 0.4912 - video_packets_loss_output_accuracy: 0.9121 - audio_packets_loss_output_accuracy: 0.8404 - video_jitter_output_accuracy: 0.8334 - audio_jitter_output_accuracy: 0.8106 - val_loss: 1.8437 - val_video_packets_loss_output_loss: 0.2765 - val_audio_packets_loss_output_loss: 0.4901 - val_video_jitter_output_loss: 0.4729 - val_audio_jitter_output_loss: 0.5420 - val_video_packets_loss_output_accuracy: 0.9130 - val_audio_packets_loss_output_accuracy: 0.8274 - val_video_jitter_output_accuracy: 0.8294 - val_audio_jitter_output_accuracy: 0.8049
# Epoch 10/10
# 4824/4824 [==============================] - 19s 4ms/step - loss: 1.7215 - video_packets_loss_output_loss: 0.2672 - audio_packets_loss_output_loss: 0.4501 - video_jitter_output_loss: 0.4503 - audio_jitter_output_loss: 0.4908 - video_packets_loss_output_accuracy: 0.9124 - audio_packets_loss_output_accuracy: 0.8413 - video_jitter_output_accuracy: 0.8345 - audio_jitter_output_accuracy: 0.8106 - val_loss: 1.8629 - val_video_packets_loss_output_loss: 0.2770 - val_audio_packets_loss_output_loss: 0.4960 - val_video_jitter_output_loss: 0.4768 - val_audio_jitter_output_loss: 0.5494 - val_video_packets_loss_output_accuracy: 0.9114 - val_audio_packets_loss_output_accuracy: 0.8282 - val_video_jitter_output_accuracy: 0.8310 - val_audio_jitter_output_accuracy: 0.8000
#
#
#  ***** TRAINING 9
# Epoch 1/10
# 4824/4824 [==============================] - 19s 4ms/step - loss: 1.7211 - video_packets_loss_output_loss: 0.2685 - audio_packets_loss_output_loss: 0.4470 - video_jitter_output_loss: 0.4494 - audio_jitter_output_loss: 0.4926 - video_packets_loss_output_accuracy: 0.9117 - audio_packets_loss_output_accuracy: 0.8421 - video_jitter_output_accuracy: 0.8353 - audio_jitter_output_accuracy: 0.8104 - val_loss: 1.8330 - val_video_packets_loss_output_loss: 0.2754 - val_audio_packets_loss_output_loss: 0.4880 - val_video_jitter_output_loss: 0.4696 - val_audio_jitter_output_loss: 0.5374 - val_video_packets_loss_output_accuracy: 0.9120 - val_audio_packets_loss_output_accuracy: 0.8326 - val_video_jitter_output_accuracy: 0.8315 - val_audio_jitter_output_accuracy: 0.8056
# Epoch 2/10
# 4824/4824 [==============================] - 19s 4ms/step - loss: 1.7179 - video_packets_loss_output_loss: 0.2678 - audio_packets_loss_output_loss: 0.4474 - video_jitter_output_loss: 0.4507 - audio_jitter_output_loss: 0.4890 - video_packets_loss_output_accuracy: 0.9126 - audio_packets_loss_output_accuracy: 0.8422 - video_jitter_output_accuracy: 0.8339 - audio_jitter_output_accuracy: 0.8118 - val_loss: 1.8273 - val_video_packets_loss_output_loss: 0.2732 - val_audio_packets_loss_output_loss: 0.4856 - val_video_jitter_output_loss: 0.4694 - val_audio_jitter_output_loss: 0.5372 - val_video_packets_loss_output_accuracy: 0.9121 - val_audio_packets_loss_output_accuracy: 0.8291 - val_video_jitter_output_accuracy: 0.8333 - val_audio_jitter_output_accuracy: 0.8084
# Epoch 3/10
# 4824/4824 [==============================] - 20s 4ms/step - loss: 1.7158 - video_packets_loss_output_loss: 0.2666 - audio_packets_loss_output_loss: 0.4460 - video_jitter_output_loss: 0.4523 - audio_jitter_output_loss: 0.4874 - video_packets_loss_output_accuracy: 0.9120 - audio_packets_loss_output_accuracy: 0.8419 - video_jitter_output_accuracy: 0.8342 - audio_jitter_output_accuracy: 0.8116 - val_loss: 1.8388 - val_video_packets_loss_output_loss: 0.2735 - val_audio_packets_loss_output_loss: 0.4909 - val_video_jitter_output_loss: 0.4756 - val_audio_jitter_output_loss: 0.5351 - val_video_packets_loss_output_accuracy: 0.9130 - val_audio_packets_loss_output_accuracy: 0.8279 - val_video_jitter_output_accuracy: 0.8290 - val_audio_jitter_output_accuracy: 0.8070
# Epoch 4/10
# 4824/4824 [==============================] - 19s 4ms/step - loss: 1.7202 - video_packets_loss_output_loss: 0.2676 - audio_packets_loss_output_loss: 0.4482 - video_jitter_output_loss: 0.4519 - audio_jitter_output_loss: 0.4894 - video_packets_loss_output_accuracy: 0.9117 - audio_packets_loss_output_accuracy: 0.8423 - video_jitter_output_accuracy: 0.8339 - audio_jitter_output_accuracy: 0.8118 - val_loss: 1.8395 - val_video_packets_loss_output_loss: 0.2767 - val_audio_packets_loss_output_loss: 0.4911 - val_video_jitter_output_loss: 0.4718 - val_audio_jitter_output_loss: 0.5375 - val_video_packets_loss_output_accuracy: 0.9115 - val_audio_packets_loss_output_accuracy: 0.8316 - val_video_jitter_output_accuracy: 0.8311 - val_audio_jitter_output_accuracy: 0.8029
# Epoch 5/10
# 4824/4824 [==============================] - 19s 4ms/step - loss: 1.7168 - video_packets_loss_output_loss: 0.2667 - audio_packets_loss_output_loss: 0.4480 - video_jitter_output_loss: 0.4511 - audio_jitter_output_loss: 0.4873 - video_packets_loss_output_accuracy: 0.9118 - audio_packets_loss_output_accuracy: 0.8419 - video_jitter_output_accuracy: 0.8336 - audio_jitter_output_accuracy: 0.8116 - val_loss: 1.8483 - val_video_packets_loss_output_loss: 0.2812 - val_audio_packets_loss_output_loss: 0.4868 - val_video_jitter_output_loss: 0.4777 - val_audio_jitter_output_loss: 0.5410 - val_video_packets_loss_output_accuracy: 0.9100 - val_audio_packets_loss_output_accuracy: 0.8303 - val_video_jitter_output_accuracy: 0.8283 - val_audio_jitter_output_accuracy: 0.8061
# Epoch 6/10
# 4824/4824 [==============================] - 20s 4ms/step - loss: 1.7139 - video_packets_loss_output_loss: 0.2650 - audio_packets_loss_output_loss: 0.4454 - video_jitter_output_loss: 0.4516 - audio_jitter_output_loss: 0.4881 - video_packets_loss_output_accuracy: 0.9125 - audio_packets_loss_output_accuracy: 0.8439 - video_jitter_output_accuracy: 0.8344 - audio_jitter_output_accuracy: 0.8123 - val_loss: 1.8440 - val_video_packets_loss_output_loss: 0.2769 - val_audio_packets_loss_output_loss: 0.4980 - val_video_jitter_output_loss: 0.4767 - val_audio_jitter_output_loss: 0.5290 - val_video_packets_loss_output_accuracy: 0.9115 - val_audio_packets_loss_output_accuracy: 0.8271 - val_video_jitter_output_accuracy: 0.8297 - val_audio_jitter_output_accuracy: 0.8100
# Epoch 7/10
# 4824/4824 [==============================] - 19s 4ms/step - loss: 1.7090 - video_packets_loss_output_loss: 0.2652 - audio_packets_loss_output_loss: 0.4455 - video_jitter_output_loss: 0.4476 - audio_jitter_output_loss: 0.4869 - video_packets_loss_output_accuracy: 0.9131 - audio_packets_loss_output_accuracy: 0.8426 - video_jitter_output_accuracy: 0.8353 - audio_jitter_output_accuracy: 0.8128 - val_loss: 1.8537 - val_video_packets_loss_output_loss: 0.2833 - val_audio_packets_loss_output_loss: 0.4942 - val_video_jitter_output_loss: 0.4720 - val_audio_jitter_output_loss: 0.5403 - val_video_packets_loss_output_accuracy: 0.9099 - val_audio_packets_loss_output_accuracy: 0.8344 - val_video_jitter_output_accuracy: 0.8313 - val_audio_jitter_output_accuracy: 0.8032
# Epoch 8/10
# 4824/4824 [==============================] - 20s 4ms/step - loss: 1.7090 - video_packets_loss_output_loss: 0.2645 - audio_packets_loss_output_loss: 0.4455 - video_jitter_output_loss: 0.4479 - audio_jitter_output_loss: 0.4874 - video_packets_loss_output_accuracy: 0.9134 - audio_packets_loss_output_accuracy: 0.8428 - video_jitter_output_accuracy: 0.8357 - audio_jitter_output_accuracy: 0.8115 - val_loss: 1.8393 - val_video_packets_loss_output_loss: 0.2745 - val_audio_packets_loss_output_loss: 0.4939 - val_video_jitter_output_loss: 0.4695 - val_audio_jitter_output_loss: 0.5385 - val_video_packets_loss_output_accuracy: 0.9121 - val_audio_packets_loss_output_accuracy: 0.8305 - val_video_jitter_output_accuracy: 0.8335 - val_audio_jitter_output_accuracy: 0.8018
# Epoch 9/10
# 4824/4824 [==============================] - 20s 4ms/step - loss: 1.7102 - video_packets_loss_output_loss: 0.2652 - audio_packets_loss_output_loss: 0.4448 - video_jitter_output_loss: 0.4495 - audio_jitter_output_loss: 0.4870 - video_packets_loss_output_accuracy: 0.9129 - audio_packets_loss_output_accuracy: 0.8436 - video_jitter_output_accuracy: 0.8354 - audio_jitter_output_accuracy: 0.8122 - val_loss: 1.8264 - val_video_packets_loss_output_loss: 0.2707 - val_audio_packets_loss_output_loss: 0.4831 - val_video_jitter_output_loss: 0.4728 - val_audio_jitter_output_loss: 0.5358 - val_video_packets_loss_output_accuracy: 0.9137 - val_audio_packets_loss_output_accuracy: 0.8312 - val_video_jitter_output_accuracy: 0.8323 - val_audio_jitter_output_accuracy: 0.8039
# Epoch 10/10
# 4824/4824 [==============================] - 19s 4ms/step - loss: 1.7059 - video_packets_loss_output_loss: 0.2637 - audio_packets_loss_output_loss: 0.4422 - video_jitter_output_loss: 0.4496 - audio_jitter_output_loss: 0.4862 - video_packets_loss_output_accuracy: 0.9134 - audio_packets_loss_output_accuracy: 0.8434 - video_jitter_output_accuracy: 0.8343 - audio_jitter_output_accuracy: 0.8126 - val_loss: 1.8282 - val_video_packets_loss_output_loss: 0.2728 - val_audio_packets_loss_output_loss: 0.4853 - val_video_jitter_output_loss: 0.4694 - val_audio_jitter_output_loss: 0.5373 - val_video_packets_loss_output_accuracy: 0.9137 - val_audio_packets_loss_output_accuracy: 0.8323 - val_video_jitter_output_accuracy: 0.8336 - val_audio_jitter_output_accuracy: 0.8094

# %%
# Evaluate the model on the validation set
ev  = model.evaluate(X_test, [y_test[:,0], y_test[:,1], y_test[:,2], y_test[:,3]])
print("\n",ev)
# Out:
# 1206/1206 [==============================] - 1s 1ms/step - loss: 1.8282 - video_packets_loss_output_loss: 0.2728 - audio_packets_loss_output_loss: 0.4853 - video_jitter_output_loss: 0.4694 - audio_jitter_output_loss: 0.5373 - video_packets_loss_output_accuracy: 0.9137 - audio_packets_loss_output_accuracy: 0.8323 - video_jitter_output_accuracy: 0.8336 - audio_jitter_output_accuracy: 0.8094
#
#  [1.828161597251892, 0.2727714478969574, 0.4852987825870514, 0.46943095326423645, 0.5372521281242371, 0.9136867523193359, 0.8322968482971191, 0.8336442708969116, 0.8093646168708801]

# %%
# Out:
# dict_keys(['loss', 'video_packets_loss_output_loss', 'audio_packets_loss_output_loss', 'video_jitter_output_loss', 'audio_jitter_output_loss', 'video_packets_loss_output_accuracy', 'audio_packets_loss_output_accuracy', 'video_jitter_output_accuracy', 'audio_jitter_output_accuracy', 'val_loss', 'val_video_packets_loss_output_loss', 'val_audio_packets_loss_output_loss', 'val_video_jitter_output_loss', 'val_audio_jitter_output_loss', 'val_video_packets_loss_output_accuracy', 'val_audio_packets_loss_output_accuracy', 'val_video_jitter_output_accuracy', 'val_audio_jitter_output_accuracy'])

# %%
def plot_accuracy(history):
    
    # Plot training & validation loss values
    #plt.figure(figsize=(10, 5))
    plt.plot(history['loss'], label='Training Loss')
    if 'val_loss' in history:
        plt.plot(history['val_loss'], label='Validation Loss')
    plt.title('Model Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend(loc='upper right')
    
    plt.figure(figsize=(10, 6))

    # Plot training & validation loss values
    plt.subplot(2, 2, 1)
    plt.plot(history['video_packets_loss_output_accuracy'], label='Training')
    if 'val_video_packets_loss_output_accuracy' in history:
        plt.plot(history['val_video_packets_loss_output_accuracy'], label='Validation')
    plt.title('video_packets_loss Output Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend(loc='lower right')

    # Plot training & validation delay_output accuracy values
    plt.subplot(2, 2, 2)
    plt.plot(history['audio_packets_loss_output_accuracy'], label='Training')
    if 'val_audio_packets_loss_output_accuracy' in history:
        plt.plot(history['val_audio_packets_loss_output_accuracy'], label='Validation')
    plt.title('audio_packets_loss Output Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend(loc='lower right')

    # Plot training & validation jitter_output accuracy values
    plt.subplot(2, 2, 3)
    plt.plot(history['video_jitter_output_accuracy'], label='Training')
    if 'val_video_jitter_output_accuracy' in history:
        plt.plot(history['val_video_jitter_output_accuracy'], label='Validation')
    plt.title('video_jitter Output Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend(loc='lower right')

    # Plot training & validation packet_loss_output accuracy values
    plt.subplot(2, 2, 4)
    plt.plot(history['audio_jitter_output_accuracy'], label='Training')
    if 'val_audio_jitter_output_accuracy' in history:
        plt.plot(history['val_audio_jitter_output_accuracy'], label='Validation')
    plt.title('audio_jitter Output Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend(loc='lower right')

    plt.tight_layout()
    plt.show()
    
plot_accuracy(combine_histories(history_list))
#plot_accuracy(history_list[0])

# %%
for k in history_list[0].history.keys():
    history_list[0].history[k] = history_list[0].history[k][:10]
